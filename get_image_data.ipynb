# %%
import requests
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
url = "https://upload.wikimedia.org/wikipedia/commons/6/67/Jason_Ensler.jpg"

# %%
r = requests.get(url, allow_redirects=True)

# %%
content = r.content

# %%
with open('image_cache/cache.jpg', 'wb') as f:
    f.write(r.content)
image = open('image_cache/cache.jpg', 'rb')
image.read()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('image_cache/cache.jpg')

# %%
from io import BytesIO
from PIL import Image

# byteImgIO = BytesIO()
# byteImg = Image.open("some/location/to/a/file/in/my/directories.png")
# byteImg.save(byteImgIO, "PNG")
# byteImgIO.seek(0)
# byteImg = byteImgIO.read()


file_url = "https://upload.wikimedia.org/wikipedia/commons/3/3a/Cat03.jpg"
r = requests.get(file_url, allow_redirects=True, stream=True)
i = Image.open(BytesIO(r.content))
print(BytesIO(r.content).read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x01\x00H\x00H\x00\x00\xff\xe1\x17*Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x07\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00b\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00j\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x1c\x00\x00\x00r\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\x8e\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xa4\x00\x00\x00\xd0\x00\n\xfc\x80\x00\x00\'\x10\x00\n\xfc\x80\x00\x00\'\x10Adobe Photoshop CS4 Windows\x002009:01:31 22:25:45\x00\x00\x00\x00\x03\xa0\x01\x00\x03\x00\x00\x00\x01\xff\xff\x00\x00\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x06@\xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x06>\x00\x00\x00\x00\x00\x00\x00\x06\x01\x03\x00\x03\x00\x00\x00\x01\x00\x06\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x01\x1e\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x01&\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x02\x01\x00\x04\x00\x00\x00\x01\x00\x00\x01.\x02\x02\x00\x04\x00
# ...

# %%
i = Image.open('image_cache/Cat03.jpg')
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1598>
