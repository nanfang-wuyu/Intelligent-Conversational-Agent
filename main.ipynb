# %%
from sentence_transformers import SentenceTransformer, util
from transformers import pipeline

# %%
sent_sim = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
model = sent_sim

# %%
model2_nlp = pipeline('ner', model='dbmdz/bert-large-cased-finetuned-conll03-english')

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
# from transformers import pipeline
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model3 = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

model3_nlp = pipeline("ner", model=model3, tokenizer=tokenizer)

# %%
qs_origin = []
Q_ents = []

qs_origin.extend([
    "Who is the director of Good Will Hunting?",
    "Who directed The Bridge on the River Kwai?",
    "Who is the director of Star Wars: Episode VI - Return of the Jedi?",
])

Q_ents.extend([
    "Good Will Hunting",
    "The Bridge on the River Kwai",
    "Star Wars: Episode VI - Return of the Jedi",
]) # should be extract by model

qs_origin.extend([
    "Who is the screenwriter of The Masked Gang: Cyprus?",
    "What is the MPAA film rating of Weathering with You?",
    "What is the genre of Good Neighbors?",
])

Q_ents.extend([
    "The Masked Gang: Cyprus",
    "Weathering with You",
    "Good Neighbors",
])

qs_origin.extend([
    "What is the box office of The Princess and the Frog?",
    "Can you tell me the publication date of Tom Meets Zizou?",
    "Who is the executive producer of X-Men: First Class?",
])

Q_ents.extend([
    "The Princess and the Frog",
    "Tom Meets Zizou",
    "X-Men: First Class",
])

qs_origin.extend([
    "Show me a picture of Halle Berry.",
    "What does Julia Roberts look like?",
    "Let me know what Sandra Bullock looks like.",
])

Q_ents.extend([
    "Halle Berry",
    "Julia Roberts",
    "Sandra Bullock",
])# TODO if many ents a question

import pandas as pd

Name_Qwiki_Qid = pd.read_csv('name_Qwiki_Qid.tsv', sep='\t')
Name_Qwiki_Qid[-5:]

names = Name_Qwiki_Qid['Str']
import numpy as np
name_embeddings = np.load("name_embeddings.npy")

import torch




def ner_test(X, y, names=names,   name_embeddings=name_embeddings, model_ner=model2_nlp, model_sent_sim=sent_sim, strategy='simple'):

    all_ents = []
    for i, q in enumerate(X):
        preds = model_ner(q, aggregation_strategy=strategy)
        if len(preds) == 0:
            print("---Try model 3---")
            preds = model3_nlp(q, aggregation_strategy=strategy)
            if len(preds) == 0:
                print(q)
                print('No name entity was found.')
                all_ents.append(q)
            else:
                all_ent = q[preds[0]['start']: preds[-1]['end']]
                all_ents.append(all_ent)
        else:
            all_ent = q[preds[0]['start']: preds[-1]['end']]
            # remove substring 'xxx rating' done
            all_ents.append(all_ent)

    all_ents_embeddings = model_sent_sim.encode(all_ents)
    sims = util.pytorch_cos_sim(torch.tensor(all_ents_embeddings), torch.tensor(name_embeddings))
    idx = torch.max(sims, 1).indices
    
    ner_pred = all_ents
    y_pred = np.array([names[int(id)] for id in idx])
    print(y_pred)
    y = np.array(y)
    for i in range(len(y)):
        if y_pred[i]!=y[i]:
            # print("-----------------------------")
            print("Question: {}".format(X[i]))
            print("NER prediction: {}".format(ner_pred[i]))
            print("NER matching: {}".format(y_pred[i]))
            print("Ground truth: {}".format(y[i]))
            print("-----------------------------")
            # print(X[i], ner_pred[i], y_pred[i], y[i], )
    accuracy = np.mean(y==y_pred)
    return accuracy

# small_data = pd.read_csv('Datasets/Relations_small_X_y.tsv', sep='\t')
# i, step = 0, 30
# acc = ner_test(list(small_data['X'][i:i+step]), list(small_data['y'][i:i+step]))
# acc = ner_test(["What is the MPAA film rating of Weathering with You?",], ["Weathering with You"])
# print(acc)

def ner_app(q, names=names,   name_embeddings=name_embeddings, model_ner=model2_nlp, model_sent_sim=sent_sim, strategy='simple'):

    pred_ent = ''
    
    preds = model_ner(q, aggregation_strategy=strategy)
    if len(preds) == 0:
        print("---Try model 3---")
        preds = model3_nlp(q, aggregation_strategy=strategy)
        if len(preds) == 0:
            print(q)
            print('No name entity was found.')
            pred_ent = q
        else:
            pred_ent = q[preds[0]['start']: preds[-1]['end']]
    else:
        pred_ent = q[preds[0]['start']: preds[-1]['end']]

    all_ents_embeddings = model_sent_sim.encode(pred_ent)
    sims = util.pytorch_cos_sim(torch.tensor(all_ents_embeddings), torch.tensor(name_embeddings))
    idx = torch.max(sims, 1).indices
    # print(int(idx))
    y_pred = names[int(idx[0])]

    if y_pred in q:
        q = q.replace(y_pred, '<>')
    
    return y_pred, q


# Q, mask_q = ner_app("What is the MPAA film rating of Weathering with You?")
# print(Q, mask_q)

def ner_for_recommend(q, names=names,   name_embeddings=name_embeddings, model_ner=model2_nlp, model_sent_sim=sent_sim, strategy='simple'):

    Qs = []
    preds = model_ner(q, aggregation_strategy=strategy)
    if len(preds) == 0:
        print("---Try model 3---")
        preds = model3_nlp(q, aggregation_strategy=strategy)
        if len(preds) == 0:
            print(q)
            print('No name entity was found.')
            ents = [q]
        else:
            ents = [pred['word'] for pred in preds ]
    else:
        ents = [pred['word'] for pred in preds ]
    

    ents_embeddings = model_sent_sim.encode(ents)
    sims = util.pytorch_cos_sim(torch.tensor(ents_embeddings), torch.tensor(name_embeddings))
    idx = torch.max(sims, 1).indices
    # print(idx)
    for id in np.array(idx):
        Qs.append(names[id])

    return Qs

# print(ner_for_recommend("Recommend movies similar to Hamlet and Othello."))
# print(ner_for_recommend("Recommend movies like Nightmare on Elm Street, Friday the 13th, and Halloween."))
# print(ner_for_recommend("Given that I like The Lion King, Pocahontas, and The Beauty and the Beast, can you recommend some movies?"))

import yake
kw_extractor = yake.KeywordExtractor()
# text = """spaCy is an open-source software library for advanced natural language processing, written in the programming languages Python and Cython. The library is published under the MIT license and its main developers are Matthew Honnibal and Ines Montani, the founders of the software company Explosion."""
# text = """Who is the director of ?"""
# text = """Who directed ?"""
# text = """What is the MPAA film rating of?"""
# text = """Let me know what  looks like."""
# text = """Who directed ?"""
# text = """Let me know what  looks like"""
text = """Show me a picture of ."""
language = "en"
max_ngram_size = 8
deduplication_threshold = 0.9
numOfKeywords = 1
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)

import pickle
with open('P2label.pickle', 'rb') as handle:
    P2label = pickle.load(handle)
with open('label2P.pickle', 'rb') as handle:
    label2P = pickle.load(handle)
labels = list(P2label.values())

Name2Qid = dict(zip(Name_Qwiki_Qid['Str'], Name_Qwiki_Qid['Qid']))
Qid2Name = dict(zip(Name_Qwiki_Qid['Qid'], Name_Qwiki_Qid['Str']))

labels = list(P2label.values())

special_conditions_reverse = {'description': '<http://schema.org/description>',
       'label': '<http://www.w3.org/2000/01/rdf-schema#label>',
       'tag': '<http://ddis.ch/atai/tag>', 'rating': '<http://ddis.ch/atai/rating>'}
extension_common = ['description', 'label', 'tag', 'rating']
extension_recommend = ['recommend']
extension_multimedia = ['look like'] # seem; appear; look like; look; resemble; bear resemblance to; be like.
labels.extend(extension_common)
labels.extend(extension_recommend)
labels.extend(extension_multimedia)

label_embeddings = model.encode(labels)

# def label_prediction(questions, use_keywords=True, use_expanding=False):
#     keywords = questions
#     if use_keywords:
#         keywords = []
#         for q in questions:
#             keyword = custom_kw_extractor.extract_keywords(q)
#             if not keyword:
#                 print("Use whole question")
#                 keywords.append(q)
#             else:
#                 print("Keyword: ", keyword[0][0])
#                 keywords.append(keyword[0][0])

#         print("Keywords: ", keywords)
    
#     question_embeddings = model.encode(keywords)
#     # print(question_embeddings)
#     preds = []
#     for embd in question_embeddings:
#         results = [util.pytorch_cos_sim(embd, label) for label in label_embeddings]
#         pred = labels[results.index(max(results))]
#         preds.append(pred)
#     return preds

def label_prediction(question, use_keywords=True, use_expanding=False):

    if 'ecommend' in question:
        return 'recommend'
    
    keywords = [question]
    if use_keywords:
        keywords = []
        keyword = custom_kw_extractor.extract_keywords(question)
        if not keyword:
            print("Use whole question")
            keywords.append(question)
        else:
            print("Keyword: ", keyword[0][0])
            keywords.append(keyword[0][0])

        print("Keywords: ", keywords)
    
    question_embeddings = model.encode(keywords)
    # print(question_embeddings)

    sims = util.pytorch_cos_sim(torch.tensor(question_embeddings), torch.tensor(label_embeddings))
    idx = torch.max(sims, 1).indices
    y_pred = labels[int(idx[0])]

    return y_pred

from rdflib.namespace import Namespace, RDF, RDFS, XSD
from rdflib.term import URIRef, Literal
import csv
import json
import networkx as nx
import rdflib
import pywikibot

graph = rdflib.Graph()
graph.parse('Datasets/14_graph.nt', format='turtle')


def Qwiki2name_func(Qwiki: str):
    if Qwiki == None:
        return None
    if not Qwiki.startswith('http'):
        Qwiki = 'http://www.wikidata.org/entity/{}'.format(Qwiki)
    sql = \
        """
    prefix wdt: <http://www.wikidata.org/prop/direct/> 
    prefix wd: <http://www.wikidata.org/entity/> 
    SELECT ?lbl
    WHERE{
    <%s> rdfs:label ?lbl.
    FILTER(LANG(?lbl)='en')
    }

    """ % (Qwiki)

    tl = list(graph.query(sql))
    if len(tl)>0:
        for t in tl:
            for m in t:
                print(str(m))
                return str(m)
    else:
        return None

def name2Qid_func(name: str, func=1):
    if name == None:
        return None
    if func==1:
    
        sql1 = \
        """
    prefix wdt: <http://www.wikidata.org/prop/direct/> 
    prefix wd: <http://www.wikidata.org/entity/> 
    SELECT ?Qid
    WHERE{
    # ?Qid rdfs:label "%s"@en .
    }

    """ % (name)

        sql2 = \
        """
    prefix wdt: <http://www.wikidata.org/prop/direct/> 
    prefix wd: <http://www.wikidata.org/entity/> 
    SELECT ?Qid
    WHERE{
    # ?Qid rdfs:label "%s"@en.
    # ?Qid wdt:P31/wdt:P279* wd:Q11424
    
    }

    """ % (name)
    
    

        Qids = []
        tl = list(graph.query(sql1))
        for t in tl:
            for m in t:
                Qids.append(str(m).removeprefix("http://www.wikidata.org/entity/"))
        # print(len(Qids))
        if len(Qids) == 0:
            print('Name2Qid failed, name: {}'.format(name))
            return None
        elif len(Qids) == 1:
            return Qids[0]
        
        elif len(Qids) > 1:
            Qids2 = []
            tl2 = list(graph.query(sql2))
            # print("TL:", tl2)
            for t in tl2:
                for m in t:
                    Qids2.append(str(m).removeprefix("http://www.wikidata.org/entity/"))
            if len(Qids2) >= 1:
                return np.random.choice(Qids2)
            else: 
                # print(Qids)
                return np.random.choice(Qids)
        
    else:
        if name in Name2Qid.keys():
            # "Star Wars: Episode VI - Return of the Jedi"
            return Name2Qid[name]
        else:
            print('Name2Qid failed, name: {}'.format(name))
            return None

def label2Pid_func(label):
    if label in extension_multimedia:
        return label2P['image']

    if label in label2P.keys():
        return label2P[label]
    else:
        print('Label2Pid failed.')
        return None


recommend_labels = ['recommend']
multimedia_labels = ['image', 'look like']
special_conditions_reverse = {'description': '<http://schema.org/description>',
       'label': '<http://www.w3.org/2000/01/rdf-schema#label>',
       'tag': '<http://ddis.ch/atai/tag>', 'rating': '<http://ddis.ch/atai/rating>'}

def distinguish_question_type(pred):
    question_type = 'common'
    if pred in special_conditions_reverse.keys():
        question_type = 'special'
        
    elif pred in recommend_labels:
        question_type = 'recommend'

    elif pred in multimedia_labels:
        question_type = 'multimedia'
    return question_type

def answer_special_questions(Q, P):
    Qid = name2Qid_func(Q)
    Puri = special_conditions_reverse[P]
    common_sql = \
"""
prefix wdt: <http://www.wikidata.org/prop/direct/> 
prefix wd: <http://www.wikidata.org/entity/> 
SELECT ?item
WHERE{
  wd:%s %s ?item .
}
""" % (Qid, Puri)
    results = [str(s) for s, in graph.query(common_sql)]
    if len(results):
      # print(common_sql)
      return results[0]
    else:
      print('Answer special questions failed, sql: {}'.format(common_sql))
      return None

def answer_factual_questions(Q, P, func='fac'):

    Qid = name2Qid_func(Q)
    Pid = label2Pid_func(P)
    common_sql = \
"""
prefix wdt: <http://www.wikidata.org/prop/direct/> 
prefix wd: <http://www.wikidata.org/entity/> 
SELECT ?label
WHERE{
  wd:%s wdt:%s ?item .
  # ?item rdfs:label ?label .
  FILTER(LANG(?label) = "en").
}
""" % (Qid, Pid)
    results = [str(s) for s, in graph.query(common_sql)]
    if len(results):
      # print(common_sql)
      return results[:3]
    else:
      print('Answer factual questions failed.'.format(common_sql))
      return None

from sklearn.metrics import pairwise_distances
WD = rdflib.Namespace('http://www.wikidata.org/entity/')
WDT = rdflib.Namespace('http://www.wikidata.org/prop/direct/')
DDIS = rdflib.Namespace('http://ddis.ch/atai/')
RDFS = rdflib.namespace.RDFS
SCHEMA = rdflib.Namespace('http://schema.org/')

entity_emb = np.load('Datasets/EmbeddingData/entity_embeds.npy')
relation_emb = np.load('Datasets/EmbeddingData/relation_embeds.npy')

with open('Datasets/EmbeddingData/entity_ids.del', 'r') as ifile:
    ent2id = {rdflib.term.URIRef(ent): int(idx) for idx, ent in csv.reader(ifile, delimiter='\t')}
    id2ent = {v: k for k, v in ent2id.items()}
with open('Datasets/EmbeddingData/relation_ids.del', 'r') as ifile:
    rel2id = {rdflib.term.URIRef(rel): int(idx) for idx, rel in csv.reader(ifile, delimiter='\t')}
    id2rel = {v: k for k, v in rel2id.items()}

ent2lbl = {ent: str(lbl) for ent, lbl in graph.subject_objects(RDFS.label)}
lbl2ent = {lbl: ent for ent, lbl in ent2lbl.items()}

# def answer_embedding_questions(Q, P, func='emb'):

#     Qid = name2Qid_func(Q)
#     Pid = label2Pid_func(P)
#     head = entity_emb[ent2id[WD[Qid]]]
#     pred = relation_emb[rel2id[WDT[Pid]]]
#     # add vectors according to TransE scoring function.
#     lhs = head + pred
#     # compute distance to *any* entity
#     dist = pairwise_distances(lhs.reshape(1, -1), entity_emb).reshape(-1)
#     # find most plausible entities
#     most_likely = dist.argsort()

#     print([(id2ent[idx][len(WD):], ent2lbl[id2ent[idx]], dist[idx], i) for i, idx in enumerate(most_likely[:3])])
#     emb_result = ent2lbl[id2ent[most_likely[0]]]

#     return emb_result

def answer_embedding_questions(Q, P, func='emb'):
    
    Qid = name2Qid_func(Q)
    Pid = label2Pid_func(P)

    if (WD[Qid] not in ent2id.keys()) or (WDT[Pid] not in rel2id.keys()):
        return None
    head = entity_emb[ent2id[WD[Qid]]]
    pred = relation_emb[rel2id[WDT[Pid]]]
    # add vectors according to TransE scoring function.
    lhs = head + pred
    # compute distance to *any* entity
    dist = pairwise_distances(lhs.reshape(1, -1), entity_emb).reshape(-1)
    # find most plausible entities
    most_likely = dist.argsort()

    # print([(id2ent[idx][len(WD):], ent2lbl[id2ent[idx]], dist[idx], i) for i, idx in enumerate(most_likely[:3])])
    emb_result = ent2lbl[id2ent[most_likely[0]]]

    return emb_result

cro_df = pd.read_csv('Datasets/CrowdData/Clean_Cro.tsv', sep='\t')

def answer_crowdsourcing_questions(Q, P, func='cro', use_id=False):

    
    if use_id:
        Qid = Q
        Pid = P
    else:
        Qid = name2Qid_func(Q)
        Pid = label2Pid_func(P)

    # print(Qid, Pid)
    
    micro_task = cro_df.loc[(cro_df['Input1ID']=='wd:{}'.format(Qid)) & (cro_df['Input2ID']=='wdt:{}'.format(Pid))]
    if len(micro_task) > 0:
        #   GroupAnswers | TrueCount | FalseCount | Agreement
        #   FixPosition | FixValue 
        #   Input3ID
        GroupAnswers, TrueCount, FalseCount, Agreement, FixPositions, FixValues, Input3ID = (
        list(micro_task['GroupAnswers'])[0], 
        list(micro_task['TrueCount'])[0],
        list(micro_task['FalseCount'])[0],
        list(micro_task['Agreement'])[0],
        list(micro_task['FixPosition']),
        list(micro_task['FixValue']),
        str(list(micro_task['Input3ID'])[0]),
        )
        print(Input3ID)
        response_type = 'correct'
        if GroupAnswers == True:
            # use the provided answer

            if not Input3ID.startswith('wd:'):
                # return string
                cro_result = Input3ID
            else:
                # transfer id to label
                Qid = Input3ID[3:]
                cro_result = Qwiki2name_func(Qid)
        else:
           

            # fix or mention
            fixable = micro_task[micro_task['FixPosition'].str.contains('Object') & (~micro_task['FixValue'].str.contains('Empty'))]
            # if FixPositions != 'Empty' and FixValues != 'Empty':
            # both_not_empty = micro_task[(~micro_task['FixPosition'].str.contains('Empty')) & (~micro_task['FixValue'].str.contains('Empty'))]

            if len(fixable) > 0:
                fix_values = fixable['FixValue'].unique()
                value = fix_values[0]
                # fix
                response_type = 'fix'
                if value.startswith('wd:'):
                    value = value[3:]
                if value.startswith('Q'):
                    cro_result = Qwiki2name_func(value)
                else:
                    cro_result = value
                
                
            else:
                if Input3ID[:3] != 'wd:':
                    # return string
                    cro_result = Input3ID
                else:
                    # transfer id to label
                    Qid = Input3ID[3:]
                    cro_result = Qwiki2name_func(Qid)
                # just mention
                # The answer in knowledge graph is wrong -- according to the crowd, ~~~
                response_type = 'mention'

                

        return {
        'response_type': response_type,
        'result': cro_result,
        'TrueCount': TrueCount, 
        'FalseCount': FalseCount,
        'Agreement': Agreement,
        }

    else:
        print('what')
        return None



def answer_common_questions(Q, P, func='cro'):
    # fuc: fac, emb, cro
    answer = answer_crowdsourcing_questions(Q, P)
    if answer:
      return {'type': 'cro', 'answer': answer}
    else:
      answer_fac = answer_factual_questions(Q, P)
      answer_emb = answer_embedding_questions(Q, P)
      if answer_fac == None and answer_emb == None:
        return None
      elif answer_fac != None and answer_emb == None:
        return {'type': 'fac', 'answer': answer_fac}
      elif answer_fac == None and answer_emb != None:
        return {'type': 'emb', 'answer': answer_emb}
      else:
        return {'type': 'fac and emb', 'answer': (answer_emb, answer_fac)}
      
with open('Datasets/ImageData/id2Code.pickle', 'rb') as handle:
    id2Code = pickle.load(handle)

def answer_multimedia_questions(Q, P):
    Qid = name2Qid_func(Q)
    print(Qid)

    sql = \
        """
    prefix wdt: <http://www.wikidata.org/prop/direct/> 
    prefix wd: <http://www.wikidata.org/entity/> 
    SELECT ?id
    WHERE{
    wd:%s wdt:P345 ?id .
    }

    """ % (Qid)

    id = ''
    tl = list(graph.query(sql))
    for t in tl:
        for m in t:
            id = str(m)
            break
    print(id)
    if id in id2Code:
        return "image:{}".format(id2Code[id])
    else:
        print("Id is not in id to code dictionary .")
        return None

def search_recommendations(Qs, map, Pids_withpre):
    print(map)
    # genres, public_dates, directors, set_in_period, tags
    
    # lines_genre = "\n".join(["?movie %s wd:%s ." % (Pids_withpre[0], name2Qid_func(list(map['genre'])[i])) for i in range(len(list(map['genre'])))]) if map['genre'] else ''
    lines_genre = "?movie %s <%s> ." % (Pids_withpre[0], map['genre']) if map['genre'] else ''


    lines_publication_date = """
    # ?movie %s ?pubdate .
    FILTER (?pubdate >= "%s-01-01"^^xsd:date)
    FILTER (?pubdate < "%s-12-31"^^xsd:date)
    """ % (Pids_withpre[1], list(map['publication_date'])[0], list(map['publication_date'])[1]) if map['publication_date'] else ''
    
    # lines_director = "\n".join(["?movie %s wd:%s ." % (Pids_withpre[2], name2Qid_func(list(map['director'])[i])) for i in range(len(list(map['director'])))]) if map['director'] else ''
    lines_director = "?movie %s <%s> ." % (Pids_withpre[2], map['director']) if map['director'] else ''


    # lines_period = """
    # ?movie wdt:P2408 ?period .
    # ?period rdfs:label "%s"@en.

    # """ % (list(map['set_in_period'])[0]) if map['set_in_period'] else ''

    lines_period = """
    # ?movie wdt:P2408 <%s> .

    """ % (map['set_in_period']) if map['set_in_period'] else ''
    
    # lines_tag = "\n".join(["?movie %s wd:%s ." % (Pids_withpre[4], name2Qid_func(list(map['tag'])[i])) for i in range(len(list(map['tag'])))]) if map['tag'] else ''

    def genreate_sql(lines_genre, lines_publication_date, lines_director, lines_period):
        sql = \
            """
        prefix wdt: <http://www.wikidata.org/prop/direct/> 
        prefix wd: <http://www.wikidata.org/entity/> 
        prefix ps: <http://www.wikidata.org/prop/statement/>
        prefix p: <http://www.wikidata.org/prop/>
        SELECT ?lb1
        WHERE{
        
        # %s\n%s\n%s\n%s

        # ?movie wdt:P31/wdt:P279* wd:Q11424 .
        # ?movie rdfs:label ?lb1 .
        FILTER(LANG(?lb1) = "en").
        }
        LIMIT 6
        """ % (lines_genre, lines_publication_date, lines_director, lines_period)
        # print(sql)
        return(sql)
    sql = genreate_sql(lines_genre, lines_publication_date, lines_director, lines_period)
    # print(sql)
    movies = set([str(s) for s, in graph.query(sql)])
    movies = movies.difference(set(Qs))

    if len(movies) == 0:
        sql = genreate_sql(lines_genre, lines_publication_date, lines_director, '')
        movies = set([str(s) for s, in graph.query(sql)])
        movies = movies.difference(set(Qs))
        if len(movies) == 0:
            sql = genreate_sql(lines_genre, lines_publication_date, '', '')
            movies = set([str(s) for s, in graph.query(sql)])
            movies = movies.difference(set(Qs))
            if len(movies) == 0:
                sql = genreate_sql(lines_genre, '', '', '')
                movies = set([str(s) for s, in graph.query(sql)])
                movies = movies.difference(set(Qs))

    
    # print(movies)
    if len(movies) > 0:
        if len(movies) > 3:
            return list(movies)[:3]
        else:
            return list(movies)
    else:
        return None
    # return list(movies)[:3] if len(movies) > 0 else None

def fetch_features_from_sql(Qid, Pids_withpre):
    sqls = []
    for i, Pid in enumerate(Pids_withpre):
      sql = \
          """
    prefix wdt: <http://www.wikidata.org/prop/direct/> 
    prefix wd: <http://www.wikidata.org/entity/> 
    SELECT ?item1
    WHERE{
    wd:%s %s ?item1 .
    # ?item1 rdfs:label ?lb1 .
    FILTER(LANG(?lb1) = "en").
    }
    """ % (Qid, Pid)
    # lb1
      sqls.append(sql)

    sqls[1] = \
          """
    prefix wdt: <http://www.wikidata.org/prop/direct/> 
    prefix wd: <http://www.wikidata.org/entity/> 
    SELECT ?lb1
    WHERE{
    wd:%s %s ?item1 .
    # ?item1 rdfs:label ?lb1 .
    FILTER(LANG(?lb1) = "en").
    }
    """ % (Qid, Pids_withpre[1])
    genres = [str(s) for s, in graph.query(sqls[0])]
    public_dates = [str(s) for s, in graph.query(sqls[1])]
    directors = [str(s) for s, in graph.query(sqls[2])]
    set_in_period = [str(s) for s, in graph.query(sqls[3])]
    tags = [str(s) for s, in graph.query(sqls[4])]


    # print("{}\n{}\n{}\n{}\n{}\n".format(genres, public_dates, directors, set_in_period, tags))
    return genres, public_dates, directors, set_in_period, tags

from collections import Counter

def analysis_recommendation(features_all):
    # Ps = ['genre', 'publication date', 'director', 'set in period'] + tag

    genres, public_dates, directors, set_in_period, tags = features_all
    def analysis_intersection(features):
        if len(features) == 0:
            return None
        intersection = set(features[0])
        for l in features[1:]:
            intersection = intersection & set(l)
        return list(intersection)[0] if len(intersection) > 0 else None

    def analysis_min_max(features):
        if len(features) == 0:
            return None
        union = set(features[0])
        for l in features[1:]:
            union = union | set(l)
        if len(union) == 0:
            return None
        dates = [int(date[:4]) for date in union]
        return min(dates), max(dates)

    def analysis_most_common(features):
        if len(features) == 0:
            return None
        li = features[0]
        for l in features[1:]:
            li.extend(l)
        if len(li) == 0:
            return None
        
        # for i, period in enumerate(li):
        #     if period[-1:] != 's':
        #         li[i] = str((int(period) // 10) * 10)+'s'
        # print(li)
        counter = Counter(li)
        # print(counter.most_common(1)[0][0])
        return counter.most_common(1)[0][0]

    analysis = analysis_most_common(genres), \
            analysis_min_max(public_dates), \
                analysis_intersection(directors), \
                    analysis_most_common(set_in_period), \
                        analysis_intersection(tags)

    
    return analysis


    # print(analysis_public_dates(['2018-08','2020-02', '2010-02', '2019']))
    
    return None

def answer_recommend_questions(Qs: list):
  
    Qids = [name2Qid_func(Q) for Q in Qs]
    print("Qids:", Qids)
    Ps = ['genre', 'publication date', 'director', 'set in period']
    Pids_withpre = ['wdt:{}'.format(label2Pid_func(P)) for P in Ps]
    tag_rdf = special_conditions_reverse['tag']
    Pids_withpre.append(tag_rdf)


    features_all = [[] for i in range(len(Pids_withpre))]
    for i, Qid in enumerate(Qids):
      features = fetch_features_from_sql(Qid, Pids_withpre)
      for j, feature in enumerate(features):
        features_all[j].append(feature)

    analysis = analysis_recommendation(features_all)

    recommend_map = {}
    recommend_map.update({"director": analysis[2]})
    recommend_map.update({"set_in_period": analysis[3]})
    recommend_map.update({"genre": analysis[0]})
    recommend_map.update({"publication_date": analysis[1]})
    
    # print(analysis_results)
    recommendations = search_recommendations(Qs, recommend_map, Pids_withpre)

    map = recommend_map
    map['director'] = Qwiki2name_func(map['director'])
    map['set_in_period'] = Qwiki2name_func(map['set_in_period'])
    map['genre'] = Qwiki2name_func(map['genre'])

      
    return recommend_map, recommendations

def answer_question(question_type, **kwargs):
    if question_type == 'common':
        return answer_common_questions(kwargs['Q'], kwargs['P'])
    elif question_type == 'recommend':
        return answer_recommend_questions(kwargs['Qs']) #list
    elif question_type == 'multimedia':
        return answer_multimedia_questions(kwargs['Q'], kwargs['P'])
    elif question_type == 'special':
        return answer_special_questions(kwargs['Q'], kwargs['P'])

def full_answer_generation_fai(answer):
    # Failed to answer question
    choices = \
    [
        "I'm sorry that I can't answer this question to you now, can you change another one?",
        "This question is a bit of hard for me, ask me another one please!",
        "Oops! It's difficult for me to show you answer to this question, ask me a new one!",
    ]

    return np.random.choice(choices)

def full_answer_generation_mul(answer):
    # Image code
    return answer

def full_answer_generation_rec(answer):
    # Failed to answer question
    map, rec = answer
    choices_1 = \
    [
        "I would recommend you these movies: {}".format(', '.join(rec)),
        "I would like to recommend these movies to you: {}".format(', '.join(rec)),
        "I suppose you will also like: {}".format(', '.join(rec)),
    ]

    
    
    choice_genre = "in the {} genre".format(map['genre']) if map['genre'] else None
    choice_director = "directed by {}".format(map['director']) if map['director'] else None
    if map["publication_date"]:
        if map["publication_date"][0] == map["publication_date"][1]:
            choice_publicated = "pulicated around {}".format(map["publication_date"][0])
        else:
            choice_publicated = "pulicated from {} to {}".format(map["publication_date"][0], map["publication_date"][1])
    else:
        choice_publicated = None
    
    choice_period = "with a background period around {}".format(map["set_in_period"]) if map["set_in_period"] else None

    merge = []
    if choice_genre:
        merge.append(choice_genre)
    if choice_director:
        merge.append(choice_director)
    if choice_publicated:
        merge.append(choice_publicated)
    if choice_period:
        merge.append(choice_period)
    other = ', '.join(merge)

    choices_2 = \
        [
            ". By aspects, movies {} may speak to you.".format(other),
            ". Besides, movies {} may to your appetite.".format(other),
            ", and you may have interest in movies {}.".format(other),
        ]

    c1 = np.random.choice(choices_1)
    c2 = np.random.choice(choices_2)

    return "{}{}".format(c1, c2)

def full_answer_generation_spe(answer):
    # special

    # choices = \
    #     [
    #         "The answer to this question is {}.".format(answer),
    #         "I know this, {}.".format(answer),
    #         "Good question, I suppose the answer is {}.".format(answer),
    #         "Hmm, a hard question, but I know the answer is {}".format(answer),
    #         "I support {} is the answer you want.".format(answer),
    #     ]

    choices = \
        [
            "The answer to this question is: {}.".format(answer),
            "I know this, {}.".format(answer),
            "Good question, I suppose the answer is: {}.".format(answer),
            "Hmm, a hard question, but I know the answer: {}".format(answer),
            "I support {} is the answer you want.".format(answer),
        ]

    return np.random.choice(choices)

def full_answer_generation_fac(answer):
    # factual

    if len(answer) == 1:
        answer = answer[0]


        choices = \
            [
                "The answer to this question is {}.".format(answer),
                "I know this, {}.".format(answer),
                "Good question, I suppose the answer is {}.".format(answer),
                "Hmm, a hard question, but I know the answer is {}".format(answer),
                "I support {} is the answer you want.".format(answer),
            ]
    elif len(answer) == 2:

        choices = \
            [
                "The answers to this question are: {}.".format(' and '.join(answer)),
                "I know this, {}.".format(' and '.join(answer)),
                "Good question, I suppose the answers will be: {}.".format(' and '.join(answer)),
                "Hmm, a hard question, but I know the answers: {}".format(' and '.join(answer)),
                "I support {} are the answers you want.".format(' and '.join(answer)),
            ]
    
    elif len(answer) > 2:

        choices = \
            [
                "The answers to this question are: {}.".format(', '.join(answer)),
                "I know this, {}.".format(', '.join(answer)),
                "Good question, I suppose the answers will be: {}.".format(', '.join(answer)),
                "Hmm, a hard question, but I know the answers: {}".format(', '.join(answer)),
                "I support {} are the answers you want.".format(', '.join(answer)),
            ]

    return np.random.choice(choices)

def full_answer_generation_emb(answer):
    # embedding

    choices = \
        [
            "According to embeddings, the answer to this question is {}.".format(answer),
            "I find the answer to this question from embeddings: {}.".format(answer),
            "Good question, I suppose the answer is {}, suggested by embeddings.".format(answer),
            "Hmm, a hard question! But I know the answer is likely to be {}, provided by embeddings.".format(answer),
            "Take the embeddings as reference, I support {} is the answer you want.".format(answer),
        ]
    

    return np.random.choice(choices)

def full_answer_generation_bot(answer):
    # factual and embedding
    # {'type': 'fac and emb', 'answer': [answer_emb, answer_fac]}

    answer_emb, answer_fac = answer
    full_emb = full_answer_generation_emb(answer_emb)

    if len(answer_fac) == 1:
        answer_fac = answer_fac[0]
        
        if answer_emb == answer_fac:
            full_fac = np.random.choice([
                "The answer is the same if I find the answer in knowledge graph.",
                "I also get the same answer from knowledge graph, what a coincidence!",
            ])
            

        else:
            full_fac = np.random.choice([
            "However, I find another possible answer in knowledge graph: {}".format(answer_fac),
            "However, the answer is different if I search it in knowledge graph: {}.".format(answer_fac),
            "Different answer would be fetched from knowledge graph: {}.".format(answer_fac)
        ])

        
    else:
        full_fac = np.random.choice([
                "However, there would be multiple answers in knowledge graph: {}.".format(', '.join(answer_fac)),
                "While multiple answers would be fetched from knowledge graph: {}.".format(', '.join(answer_fac)),
            ])


       

    return "{} {}".format(full_emb, full_fac)

def full_answer_generation_cro(answer: dict):
    # crowdsourcing
    # {
        # 'response_type': response_type, # correct fix mention
        # 'result': cro_result, # label
        # 'TrueCount': TrueCount, # int
        # 'FalseCount': FalseCount, # int
        # 'Agreement': Agreement, # float
        # }

    # London - according to the crowd, who had an inter-rater agreement of 0.72 in this batch. 
    # The answer distribution for this specific task was 2 support votes and 1 reject vote. 

    for key in answer.keys():
        if answer[key] == None:
            return full_answer_generation_fai(None)

    choices_2 = [
            "The crowd had an inter-rater agreement of {}, in the related batch. ".format(answer['Agreement']) + 
            "The answer distribution of this micro task was {} support and {} reject.".format(answer['TrueCount'], answer['FalseCount']),
            "The inter-rater agreement of relevant batch is {}. ".format(answer['Agreement']) + 
            "The concrete distribution of relevant micro task was {} support and {} reject.".format(answer['TrueCount'], answer['FalseCount']),
        ]
    info_answer = np.random.choice(choices_2)

    if answer['response_type'] == 'correct':
        part_answer = np.random.choice([
            "Hmm, a hard question! But I know the answer is probably to be {}, provided by crowd.".format(answer['result']),
            "Good question. I suppose the answer is {}, suggested by crowd.".format(answer['result']),
            "According to crowd, the answer to this question is {}.".format(answer['result']),
            "I find the answer to this question from crowd: {}.".format(answer['result']),
            "The crowd suggested that the answer is: {}.".format(answer['result'])
        ])

        
    elif answer['response_type'] == 'fix':
        part_answer = np.random.choice([
            "Hmm, a hard question! But I know the answer is probably to be {}, which is fixed by crowd.".format(answer['result']),
            "Good question. I suppose the answer is {}, fixed by crowd.".format(answer['result']),
            "According to crowd, the fixed answer to this question is {}.".format(answer['result']),
            "I find a fixed answer to this question from crowd: {}.".format(answer['result']),
            "The crowd suggested that the fixed answer is: {}".format(answer['result'])
        ])

    else:
        # mention
        part_answer = np.random.choice([
            "Hmm, a hard question! The answer is probably to be {} from knowledge graph. However, the crowd suggested that this relationship is wrong. Sorry that I don't have complete information. But I can show you some other information.".format(answer['result']),
            "Good question. The answer in knowledge graph is {}, but the crowd think it's wrong. I don't have enough information to fix it. Here is some other analysis:".format(answer['result']),
            "According to crowd, the answer to this question is wrong, although we can get it from knowledge graph: {}. Sorry that I don't have complete information. Here is some other information I want to show you.".format(answer['result']),
        ])
    
    

    return "{} {}".format(part_answer, info_answer)

def full_answer_generation(question_type, answer):
    if not answer:
        return full_answer_generation_fai(answer)
    if question_type == 'multimedia':
        return full_answer_generation_mul(answer)
    elif question_type == 'recommend':
        return full_answer_generation_rec(answer)
    elif question_type == 'special':
        return full_answer_generation_spe(answer)
    elif question_type == 'common':
        if answer['type'] == 'cro':
            return full_answer_generation_cro(answer['answer'])
        elif answer['type'] == 'emb':
            return full_answer_generation_emb(answer['answer'])
        elif answer['type'] == 'fac':
            return full_answer_generation_fac(answer['answer'])
        elif answer['type'] == 'fac and emb':
            return full_answer_generation_bot(answer['answer'])
    return full_answer_generation_fai(answer)

# %%
# def label_prediction(questions, use_keywords=True, use_expanding=False):
#     keywords = questions
#     if use_keywords:
#         keywords = []
#         for q in questions:
#             keyword = custom_kw_extractor.extract_keywords(q)
#             if not keyword:
#                 print("Use whole question")
#                 keywords.append(q)
#             else:
#                 print("Keyword: ", keyword[0][0])
#                 keywords.append(keyword[0][0])

#         print("Keywords: ", keywords)
    
#     question_embeddings = model.encode(keywords)
#     # print(question_embeddings)
#     preds = []
#     for embd in question_embeddings:
#         results = [util.pytorch_cos_sim(embd, label) for label in label_embeddings]
#         pred = labels[results.index(max(results))]
#         preds.append(pred)
#     return preds

def label_prediction(question, use_keywords=True, use_expanding=False):

    if 'ecommend' in question:
        return 'recommend'
    
    keywords = [question]
    if use_keywords:
        keywords = []
        keyword = custom_kw_extractor.extract_keywords(question)
        if not keyword:
            print("Use whole question")
            keywords.append(question)
        else:
            print("Keyword: ", keyword[0][0])
            keywords.append(keyword[0][0])

        print("Keywords: ", keywords)
    
    question_embeddings = model.encode(keywords)
    # print(question_embeddings)

    sims = util.pytorch_cos_sim(torch.tensor(question_embeddings), torch.tensor(label_embeddings))
    idx = torch.max(sims, 1).indices
    y_pred = labels[int(idx[0])]

    return y_pred

# %%
# def answer_embedding_questions(Q, P, func='emb'):
    
#     Qid = name2Qid_func(Q)
#     Pid = label2Pid_func(P)

#     if (WD[Qid] not in ent2id.keys()) or (WDT[Pid] not in rel2id.keys()):
#         return None
#     head = entity_emb[ent2id[WD[Qid]]]
#     pred = relation_emb[rel2id[WDT[Pid]]]
#     # add vectors according to TransE scoring function.
#     lhs = head + pred
#     # compute distance to *any* entity
#     dist = pairwise_distances(lhs.reshape(1, -1), entity_emb).reshape(-1)
#     # find most plausible entities
#     most_likely = dist.argsort()

#     print([(id2ent[idx][len(WD):], ent2lbl[id2ent[idx]], dist[idx], i) for i, idx in enumerate(most_likely[:3])])
#     emb_result = ent2lbl[id2ent[most_likely[0]]]

#     return emb_result

# %%
def ner_app(q, mask_p=None, names=names,   name_embeddings=name_embeddings, model_ner=model2_nlp, model_sent_sim=sent_sim, strategy='simple'):
    ori_q = q
    if mask_p:
        q = mask_p
    pred_ent = ''
    
    preds = model_ner(q, aggregation_strategy=strategy)
    if len(preds) == 0:
        print("---Try model 3---")
        preds = model3_nlp(q, aggregation_strategy=strategy)
        if len(preds) == 0:
            print(q)
            print('No name entity was found.')
            pred_ent = q
        else:
            pred_ent = q[preds[0]['start']: preds[-1]['end']]
    else:
        pred_ent = q[preds[0]['start']: preds[-1]['end']]

    all_ents_embeddings = model_sent_sim.encode(pred_ent)
    sims = util.pytorch_cos_sim(torch.tensor(all_ents_embeddings), torch.tensor(name_embeddings))
    idx = torch.max(sims, 1).indices
    # print(int(idx))
    y_pred = names[int(idx[0])]

    if y_pred in ori_q:
        ori_q = ori_q.replace(y_pred, '<>')

    
    
    return y_pred, ori_q

# %%
### Human Username: yijie.tong Password: rI5OtxGVTzWzwA
### AI Username: yijie.tong_bot Password: 3AiyYO7SLQ77MA
import time
import atexit
import getpass
import requests  # install the package via "pip install requests"
from collections import defaultdict
from io import BytesIO
from PIL import Image

# url of the speakeasy server
# url = 'https://speakeasy.ifi.uzh.ch'
url = 'https://server3.speakeasy-ai.org'
listen_freq = 3


class DemoBot:
    def __init__(self, username, password):
        self.agent_details = self.login(username, password)
        self.session_token = self.agent_details['sessionToken']
        self.chat_state = defaultdict(lambda: {'messages': defaultdict(dict), 'initiated': False, 'my_alias': None})

        atexit.register(self.logout)

    def listen(self):
        while True:
            # check for all chatrooms
            current_rooms = self.check_rooms(session_token=self.session_token)['rooms']
            print("Current rooms number: ", len(current_rooms))
            for room in current_rooms:
                # ignore finished conversations
                if room['remainingTime'] > 0:
                    room_id = room['uid']
                    if not self.chat_state[room_id]['initiated']:
                        # send a welcome message and get the alias of the agent in the chatroom
                        # self.post_message(room_id=room_id, session_token=self.session_token, message='Hi, you can send me any message and check if it is echoed in {} seconds.'.format(listen_freq))
                        self.post_message(room_id=room_id, session_token=self.session_token, message="Welcome! I'm chatbot MTon! You can ask me questions. Glad to communicate with you!")
                        self.chat_state[room_id]['initiated'] = True
                        self.chat_state[room_id]['my_alias'] = room['alias']

                    # check for all messages
                    all_messages = self.check_room_state(room_id=room_id, since=0, session_token=self.session_token)['messages']

                    # you can also use ["reactions"] to get the reactions of the messages: STAR, THUMBS_UP, THUMBS_DOWN

                    for message in all_messages:
                        if message['authorAlias'] != self.chat_state[room_id]['my_alias']:

                            # check if the message is new
                            if message['ordinal'] not in self.chat_state[room_id]['messages']:
                                self.chat_state[room_id]['messages'][message['ordinal']] = message
                                print('\t- Chatroom {} - new message #{}: \'{}\' - {}'.format(room_id, message['ordinal'], message['message'], self.get_time()))

                                ##### You should call your agent here and get the response message #####

                                # answer = 'Got your message: \'{}\' at {}.'.format(message['message'], self.get_time())
                                
                                question = message['message']
                                P = label_prediction(question)
                                question_type = distinguish_question_type(P)
                                if question_type == 'recommend':
                                    Qs = ner_for_recommend(question)
                                    answer = answer_question(question_type=question_type, Qs=Qs)
                                else:
                                    # if P in question:
                                    mask_p = question.replace(P, '<>')
                                    print("mask_p:", mask_p)
                                    Q, mask_q = ner_app(question, mask_p = mask_p)
                                    print("Q, mask_q:", Q, mask_q)
                                    P = label_prediction(mask_q)
                                    question_type = distinguish_question_type(P)
                                    if question_type == 'recommend':
                                        Qs = ner_for_recommend(question)
                                        answer = answer_question(question_type=question_type, Qs=Qs)
                                    else:
                                        print("P: {}, Q: {}".format(P, Q))
                                        answer = answer_question(question_type=question_type, Q=Q, P=P)
                                full_answer = full_answer_generation(question_type, answer)
                                print(full_answer)

                                
                                self.post_message(room_id=room_id, session_token=self.session_token, message=full_answer, )
            time.sleep(listen_freq)

    def login(self, username: str, password: str):
        agent_details = requests.post(url=url + "/api/login", json={"username": username, "password": password}).json()
        print(agent_details.keys())
        print('- User {} successfully logged in with session \'{}\'!'.format(agent_details['userDetails']['username'], agent_details['sessionToken']))
        return agent_details

    def check_rooms(self, session_token: str):
        return requests.get(url=url + "/api/rooms", params={"session": session_token}).json()

    def check_room_state(self, room_id: str, since: int, session_token: str):
        return requests.get(url=url + "/api/room/{}/{}".format(room_id, since), params={"roomId": room_id, "since": since, "session": session_token}).json()

    def post_message(self, room_id: str, session_token: str, message: str):

        ##### Try multimedia #####


        tmp_des = requests.post(url=url + "/api/room/{}".format(room_id),
                                params={"roomId": room_id, "session": session_token}, data=message).json()
        if tmp_des['description'] != 'Message received':
            print('\t\t Error: failed to post message: {}'.format(message))

    def get_time(self):
        return time.strftime("%H:%M:%S, %d-%m-%Y", time.localtime())

    def logout(self):
        if requests.get(url=url + "/api/logout", params={"session": self.session_token}).json()['description'] == 'Logged out':
            print('- Session \'{}\' successfully logged out!'.format(self.session_token))


if __name__ == '__main__':
    username = 'curiousLion3_bot'
    # password = getpass.getpass('Password of the demo bot:')
    password = '3AiyYO7SLQ77MA'
    demobot = DemoBot(username, password)
    demobot.listen()

# %%
label_prediction("What is The Machinist's CNC film rating (France)?")
# Out:
# Keyword:  Machinist CNC film rating
# Keywords:  ['Machinist CNC film rating']
# 'CNC film rating (France)'

# %% [markdown]
# ## TODO handle keys done
# ## TODO recommend in str done

# %% [markdown]
# ## Log generation

# %%
def smart_bot(question):
    P = label_prediction(question)
    question_type = distinguish_question_type(P)
    if question_type == 'recommend':
        Qs = ner_for_recommend(question)
        answer = answer_question(question_type=question_type, Qs=Qs)
    else:
        # if P in question:
        mask_p = question.replace(P, '<>')
        print("mask_p:", mask_p)
        Q, mask_q = ner_app(question, mask_p = mask_p)
        print("Q, mask_q:", Q, mask_q)
        P = label_prediction(mask_q)
        question_type = distinguish_question_type(P)
        if question_type == 'recommend':
            Qs = ner_for_recommend(question)
            answer = answer_question(question_type=question_type, Qs=Qs)
        else:
            print("P: {}, Q: {}".format(P, Q))
            answer = answer_question(question_type=question_type, Q=Q, P=P)
    full_answer = full_answer_generation(question_type, answer)
    # print(full_answer)
    return full_answer

# %%
def log_generation(questions, filename):
    f = open(filename, "w")
    for question in questions:
        answer = smart_bot(question)
        log = "Question: {}\nAnswer: {}\n".format(question, answer)
        # print(log)
        f.write(log)
    f.close()

# %%
# import logging
# logging.basicConfig(filename='example.log', encoding='utf-8', level=logging.ERROR)
# logging.debug('This message should go to the log file')
# logging.info("Question: {}\nAnswer: {}".format('123','123321'))
# logging.warning('And this, too')
# logging.error('And non-ASCII stuff, too, like Øresund and Malmö')

# %%
# log_generation(['s', 'w'], 'demofile2.txt')

# %%
example_questions = [
    "Who is the director of Good Will Hunting?",
    "Who directed The Bridge on the River Kwai?",
    "Who is the director of Star Wars: Episode VI - Return of the Jedi?",
    "Who is the screenwriter of The Masked Gang: Cyprus?",
    "What is the MPAA film rating of Weathering with You?",
    "What is the genre of Good Neighbors?",
    "Show me a picture of Halle Berry.",
    "What does Julia Roberts look like?",
    "Let me know what Sandra Bullock looks like.",
    "Show me a picture of Bruce Willis.",
    "Recommend movies similar to Hamlet and Othello.",
    "Recommend movies like Nightmare on Elm Street, Friday the 13th, and Halloween.",
    "Given that I like The Lion King, Pocahontas, and The Beauty and the Beast, can you recommend some movies?",
    "What is the box office of The Princess and the Frog?",
    "Can you tell me the publication date of Tom Meets Zizou?",
    "Who is the executive producer of X-Men: First Class?",
]

# %%
log_generation(example_questions, 'example.log')

# %%
cro_test = pd.read_csv('Datasets/Testsets/Cro_Testset.tsv', sep='\t')
fac_emb_test = pd.read_csv('Datasets/Testsets/Fac_Emb_Testset.tsv', sep='\t')
mul_test = pd.read_csv('Datasets/Testsets/Mul_Testset.tsv', sep='\t')
rec_test = pd.read_csv('Datasets/Testsets/Rec_Testset.tsv', sep='\t')

# %%
# log_generation(cro_test['Question'][:100], 'cro.log')
log_generation(fac_emb_test['Question'][:100], 'fac_emb.log')
log_generation(mul_test['Question'][:100], 'mul.log')
log_generation(rec_test['Question'][:100], 'rec.log')
# Out:
# Keyword:  assessment of Kothanodi
# Keywords:  ['assessment of Kothanodi']
# mask_p: Can you tell me the assessment of Kothanodi?
# Q, mask_q: Kothanodi Can you tell me the assessment of <>?
# Keyword:  assessment
# Keywords:  ['assessment']
# P: assessment, Q: Kothanodi
# what
# Keyword:  node description of Dan Hennessey
# Keywords:  ['node description of Dan Hennessey']
# mask_p: Tell me the node description of Dan Hennessey.
# Q, mask_q: Dan Hennessey Tell me the node description of <>.
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Dan Hennessey
# Keyword:  country of origin of Back to Burgundy
# Keywords:  ['country of origin of Back to Burgundy']
# mask_p: Can you tell me the <> of Back to Burgundy?
# Q, mask_q: Back to Burgundy Can you tell me the country of origin of <>?
# Keyword:  country of origin
# Keywords:  ['country of origin']
# P: country of origin, Q: Back to Burgundy
# what
# Keyword:  Ketchup Effect IMDb
# Keywords:  ['Ketchup Effect IMDb']
# mask_p: What is The Ketchup Effect's <>?
# Q, mask_q: The Ketchup Effect What is <>'s IMDb ID?
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: The Ketchup Effect
# what
# Answer factual questions failed.
# Keyword:  Simon Norrthon
# Keywords:  ['Simon Norrthon']
# mask_p: What is the instance of of Simon Norrthon?
# Q, mask_q: Simon Norrthon What is the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Simon Norrthon
# what
# Keyword:  Sergey Astakhov award received
# Keywords:  ['Sergey Astakhov award received']
# mask_p: What is Sergey Astakhov's <>?
# Q, mask_q: Sergey Astakhov What is <>'s award received?
# Keyword:  award received
# Keywords:  ['award received']
# P: award received, Q: Sergey Astakhov
# what
# Keyword:  cast member of St Trinian
# Keywords:  ['cast member of St Trinian']
# mask_p: Do you know the <> of St Trinian's?
# Q, mask_q: St Trinian's Do you know the cast member of <>?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: St Trinian's
# what
# Keyword:  Labyrinth node label
# Keywords:  ['Labyrinth node label']
# mask_p: What is Labyrinth's node <>?
# Q, mask_q: Labyrinth What is <>'s node label?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Labyrinth
# Keyword:  place of death of Christiane Bailly
# Keywords:  ['place of death of Christiane Bailly']
# mask_p: Do you know the <> of Christiane Bailly?
# Q, mask_q: Christiane Bailly Do you know the place of death of <>?
# Keyword:  place of death
# Keywords:  ['place of death']
# P: place of death, Q: Christiane Bailly
# what
# Keyword:  Midsommar RCQ classification
# Keywords:  ['Midsommar RCQ classification']
# mask_p: What is Midsommar's <>?
# Q, mask_q: Midsommar What is <>'s RCQ classification?
# Keyword:  RCQ classification
# Keywords:  ['RCQ classification']
# P: RCQ classification, Q: Midsommar
# what
# Keyword:  Paul Brinegar node description
# Keywords:  ['Paul Brinegar node description']
# mask_p: What is Paul Brinegar's node description?
# Q, mask_q: Paul Brinegar What is <>'s node description?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Paul Brinegar
# Keyword:  image of Edie Adams
# Keywords:  ['image of Edie Adams']
# mask_p: Do you know the image of Edie Adams?
# Q, mask_q: Edie Adams Do you know the image of <>?
# Keyword:  image
# Keywords:  ['image']
# P: image, Q: Edie Adams
# Q450646
# nm0010944
# Keyword:  assessment of Faust
# Keywords:  ['assessment of Faust']
# mask_p: Do you know the <> of Faust: Love of the Damned?
# Q, mask_q: Faust: Love of the Damned Do you know the assessment of <>?
# Keyword:  assessment
# Keywords:  ['assessment']
# P: assessment, Q: Faust: Love of the Damned
# what
# Keyword:  cast member of Gods and Monsters
# Keywords:  ['cast member of Gods and Monsters']
# mask_p: What is the <> of Gods and Monsters?
# Q, mask_q: Gods and Monsters What is the cast member of <>?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Gods and Monsters
# what
# Keyword:  Cloverfield Lane RARS rating
# Keywords:  ['Cloverfield Lane RARS rating']
# mask_p: What is 10 Cloverfield Lane's <>?
# Q, mask_q: 10 Cloverfield Lane What is <>'s RARS rating?
# Keyword:  RARS rating
# Keywords:  ['RARS rating']
# P: RARS rating, Q: 10 Cloverfield Lane
# what
# Keyword:  IMDb ID of Ned Schmidtke
# Keywords:  ['IMDb ID of Ned Schmidtke']
# mask_p: Tell me the <> of Ned Schmidtke.
# Q, mask_q: Ned Schmidtke Tell me the IMDb ID of <>.
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: Ned Schmidtke
# what
# Answer factual questions failed.
# Keyword:  Flushed Away distributed
# Keywords:  ['Flushed Away distributed']
# mask_p: What is Flushed Away <>?
# ---Try model 3---
# What is Flushed Away <>?
# No name entity was found.
# Q, mask_q: Flushed Away What is <> distributed by?
# Keyword:  distributed
# Keywords:  ['distributed']
# P: distributed by, Q: Flushed Away
# what
# Keyword:  language of film or TV show of Ghost
# Keywords:  ['language of film or TV show of Ghost']
# mask_p: What is the <> of Ghost in the Shell 2: Innocence?
# Q, mask_q: Ghost in the Shell 2: Innocence What is the original language of film or TV show of <>?
# Keyword:  original language of film or TV show
# Keywords:  ['original language of film or TV show']
# P: original language of film or TV show, Q: Ghost in the Shell 2: Innocence
# what
# Keyword:  publication date of Hornet Nest
# Keywords:  ['publication date of Hornet Nest']
# mask_p: Can you tell me the <> of Hornet's Nest?
# Q, mask_q: Hornet's Nest Can you tell me the publication date of <>?
# Keyword:  publication date
# Keywords:  ['publication date']
# P: publication date, Q: Hornet's Nest
# what
# Answer factual questions failed.
# Keyword:  instance of of One Missed
# Keywords:  ['instance of of One Missed']
# mask_p: Can you tell me the <> of One Missed Call?
# ---Try model 3---
# Q, mask_q: One Missed Call Can you tell me the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: One Missed Call
# what
# Keyword:  node description of Jan Skopeček
# Keywords:  ['node description of Jan Skopeček']
# mask_p: Do you know the node description of Jan Skopeček?
# Q, mask_q: Jan Skopeček Do you know the node description of <>?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Jan Skopeček
# Keyword:  original language of film or TV show
# Keywords:  ['original language of film or TV show']
# mask_p: What is the <> of Us?
# Q, mask_q: Us What is the original language of film or TV show of <>?
# Keyword:  original language of film or TV show
# Keywords:  ['original language of film or TV show']
# P: original language of film or TV show, Q: Us
# what
# Keyword:  characters of Beyond Blunderdome
# Keywords:  ['characters of Beyond Blunderdome']
# mask_p: Can you tell me the characters of Beyond Blunderdome?
# Q, mask_q: Beyond Blunderdome Can you tell me the characters of <>?
# Keyword:  characters
# Keywords:  ['characters']
# P: characters, Q: Beyond Blunderdome
# what
# Keyword:  Godzilla vs. Destoroyah distributed
# Keywords:  ['Godzilla vs. Destoroyah distributed']
# mask_p: What is Godzilla vs. Destoroyah <>?
# Q, mask_q: Godzilla vs. Destoroyah What is <> distributed by?
# Keyword:  distributed
# Keywords:  ['distributed']
# P: distributed by, Q: Godzilla vs. Destoroyah
# what
# Keyword:  language of film or TV show of Detention
# Keywords:  ['language of film or TV show of Detention']
# mask_p: What is the <> of Detention?
# ---Try model 3---
# What is the <> of Detention?
# No name entity was found.
# Q, mask_q: Detention What is the original language of film or TV show of <>?
# Keyword:  original language of film or TV show
# Keywords:  ['original language of film or TV show']
# P: original language of film or TV show, Q: Detention
# what
# Keyword:  cast member of One Hundred and One Nights
# Keywords:  ['cast member of One Hundred and One Nights']
# mask_p: What is the <> of One Hundred and One Nights?
# Q, mask_q: One Hundred and One Nights What is the cast member of <>?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: One Hundred and One Nights
# what
# Keyword:  CNC film rating
# Keywords:  ['CNC film rating']
# mask_p: Do you know the <> of Before Dawn?
# Q, mask_q: Before Dawn Do you know the CNC film rating (France) of <>?
# Keyword:  CNC film rating
# Keywords:  ['CNC film rating']
# P: CNC film rating (France), Q: Before Dawn
# what
# Answer factual questions failed.
# Keyword:  node description
# Keywords:  ['node description']
# mask_p: Can you tell me the node <> of 2001?
# ---Try model 3---
# Can you tell me the node <> of 2001?
# No name entity was found.
# Q, mask_q: 2001 Can you tell me the node description of <>?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: 2001
# Keyword:  image of West Side Story
# Keywords:  ['image of West Side Story']
# mask_p: What is the image of West Side Story?
# Q, mask_q: West Side Story What is the image of <>?
# Keyword:  image
# Keywords:  ['image']
# P: image, Q: West Side Story
# Q273704
# tt0055614
# Keyword:  written or signed of Bernhard Jasper
# Keywords:  ['written or signed of Bernhard Jasper']
# mask_p: Can you tell me the languages spoken, written or signed of Bernhard Jasper?
# Q, mask_q: Bernhard Jasper Can you tell me the languages spoken, written or signed of <>?
# Keyword:  languages spoken
# Keywords:  ['languages spoken']
# P: languages spoken, written or signed, Q: Bernhard Jasper
# what
# Keyword:  director of The Godfather Part III
# Keywords:  ['director of The Godfather Part III']
# mask_p: Tell me the <> of The Godfather Part III.
# Q, mask_q: The Godfather Part III Tell me the director of <>.
# Keyword:  director
# Keywords:  ['director']
# P: director, Q: The Godfather Part III
# what
# Keyword:  Double Life of Véronique cast member
# Keywords:  ['Double Life of Véronique cast member']
# mask_p: What is The Double Life of Véronique's <>?
# Q, mask_q: The Double Life of Véronique What is <>'s cast member?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: The Double Life of Véronique
# what
# Keyword:  Defenders of Riga original language of film
# Keywords:  ['Defenders of Riga original language of film']
# mask_p: What is Defenders of Riga's <>?
# Q, mask_q: Defenders of Riga What is <>'s original language of film or TV show?
# Keyword:  original language of film or TV show
# Keywords:  ['original language of film or TV show']
# P: original language of film or TV show, Q: Defenders of Riga
# what
# Keyword:  Jurassic Park country of origin
# Keywords:  ['Jurassic Park country of origin']
# mask_p: What is The Lost World: Jurassic Park's <>?
# Q, mask_q: The Lost World: Jurassic Park What is <>'s country of origin?
# Keyword:  country of origin
# Keywords:  ['country of origin']
# P: country of origin, Q: The Lost World: Jurassic Park
# what
# Keyword:  Heartbreak Hotel distributed
# Keywords:  ['Heartbreak Hotel distributed']
# mask_p: What is Heartbreak Hotel distributed by?
# Q, mask_q: Heartbreak Hotel What is <> distributed by?
# Keyword:  distributed
# Keywords:  ['distributed']
# P: distributed by, Q: Heartbreak Hotel
# what
# Keyword:  node label of Adelaide Kane
# Keywords:  ['node label of Adelaide Kane']
# mask_p: Do you know the node <> of Adelaide Kane?
# Q, mask_q: Adelaide Kane Do you know the node label of <>?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Adelaide Kane
# Keyword:  Crucible node label
# Keywords:  ['Crucible node label']
# mask_p: What is The Crucible's node <>?
# Q, mask_q: The Crucible What is <>'s node label?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: The Crucible
# Keyword:  Veronika Decides to Die instance
# Keywords:  ['Veronika Decides to Die instance']
# mask_p: What is Veronika Decides to Die's instance of?
# Q, mask_q: Veronika Decides to Die What is <>'s instance of?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Veronika Decides to Die
# what
# Keyword:  Robert Lawrence node description
# Keywords:  ['Robert Lawrence node description']
# mask_p: What is Robert Lawrence's node description?
# Q, mask_q: Robert Lawrence What is <>'s node description?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Robert Lawrence
# Keyword:  country of origin of Diggers
# Keywords:  ['country of origin of Diggers']
# mask_p: Tell me the <> of Diggers.
# Q, mask_q: Difret Tell me the country of origin of Diggers.
# Keyword:  country of origin of Diggers
# Keywords:  ['country of origin of Diggers']
# P: country of origin, Q: Difret
# what
# Keyword:  node label of La Ronde
# Keywords:  ['node label of La Ronde']
# mask_p: Can you tell me the node <> of La Ronde?
# Q, mask_q: La Ronde Can you tell me the node label of <>?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: La Ronde
# Keyword:  image of Jelka van Houten
# Keywords:  ['image of Jelka van Houten']
# mask_p: Tell me the image of Jelka van Houten.
# Q, mask_q: Jelka van Houten Tell me the image of <>.
# Keyword:  image
# Keywords:  ['image']
# P: image, Q: Jelka van Houten
# Q2199572
# nm0887206
# Keyword:  ethnic group of Scatman Crothers
# Keywords:  ['ethnic group of Scatman Crothers']
# mask_p: Tell me the <> of Scatman Crothers.
# Q, mask_q: Scatman Crothers Tell me the ethnic group of <>.
# Keyword:  ethnic group
# Keywords:  ['ethnic group']
# P: ethnic group, Q: Scatman Crothers
# what
# Keyword:  written or signed of Giancarlo Esposito
# Keywords:  ['written or signed of Giancarlo Esposito']
# mask_p: Do you know the <> of Giancarlo Esposito?
# Q, mask_q: Giancarlo Esposito Do you know the languages spoken, written or signed of <>?
# Keyword:  languages spoken
# Keywords:  ['languages spoken']
# P: languages spoken, written or signed, Q: Giancarlo Esposito
# what
# Keyword:  main subject of Broken Silence
# Keywords:  ['main subject of Broken Silence']
# mask_p: Tell me the <> of Broken Silence.
# Q, mask_q: Broken Silence Tell me the main subject of <>.
# Keyword:  main subject
# Keywords:  ['main subject']
# P: main subject, Q: Broken Silence
# what
# Keyword:  Zorak IMDb
# Keywords:  ['Zorak IMDb']
# mask_p: What is Zorak's <>?
# Q, mask_q: Zorak What is <>'s IMDb ID?
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: Zorak
# what
# Answer factual questions failed.
# Keyword:  Erasmo Olivera
# Keywords:  ['Erasmo Olivera']
# mask_p: What is the instance of of Erasmo Olivera?
# Q, mask_q: Erasmo Olivera What is the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Erasmo Olivera
# what
# Keyword:  cast member of Salvador Allende
# Keywords:  ['cast member of Salvador Allende']
# mask_p: What is the <> of Salvador Allende?
# Q, mask_q: Salvador Allende What is the cast member of <>?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Salvador Allende
# what
# Keyword:  country of citizenship of Irena Karel
# Keywords:  ['country of citizenship of Irena Karel']
# mask_p: What is the <> of Irena Karel?
# Q, mask_q: Irena Karel What is the country of citizenship of <>?
# Keyword:  country of citizenship
# Keywords:  ['country of citizenship']
# P: country of citizenship, Q: Irena Karel
# what
# Keyword:  IMDb ID of Vanessa Glodjo
# Keywords:  ['IMDb ID of Vanessa Glodjo']
# mask_p: Tell me the <> of Vanessa Glodjo.
# Q, mask_q: Vanessa Glodjo Tell me the IMDb ID of <>.
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: Vanessa Glodjo
# what
# Answer factual questions failed.
# Keyword:  Wraps named
# Keywords:  ['Wraps named']
# mask_p: Can you tell me what is Under Wraps <>?
# Q, mask_q: wrap Can you tell me what is Under Wraps named after?
# Keyword:  Wraps named
# Keywords:  ['Wraps named']
# P: named after, Q: wrap
# what
# Answer factual questions failed.
# Keyword:  Renegades director of photography
# Keywords:  ['Renegades director of photography']
# mask_p: What is Renegades's <>?
# Q, mask_q: Renegades What is <>'s director of photography?
# Keyword:  director of photography
# Keywords:  ['director of photography']
# P: director of photography, Q: Renegades
# what
# Keyword:  Dey Young spouse
# Keywords:  ['Dey Young spouse']
# mask_p: What is Dey Young's <>?
# Q, mask_q: Dey Young What is <>'s spouse?
# Keyword:  spouse
# Keywords:  ['spouse']
# P: spouse, Q: Dey Young
# what
# Keyword:  node description of Karatsu
# Keywords:  ['node description of Karatsu']
# mask_p: Do you know the node <> of Karatsu?
# Q, mask_q: Karatsu Do you know the node description of <>?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Karatsu
# Keyword:  Maureen Robinson spouse
# Keywords:  ['Maureen Robinson spouse']
# mask_p: What is Maureen Robinson's <>?
# Q, mask_q: Maureen Robinson What is <>'s spouse?
# Keyword:  spouse
# Keywords:  ['spouse']
# P: spouse, Q: Maureen Robinson
# what
# Keyword:  place of birth of Demond Wilson
# Keywords:  ['place of birth of Demond Wilson']
# mask_p: Tell me the <> of Demond Wilson.
# Q, mask_q: Demond Wilson Tell me the place of birth of <>.
# Keyword:  place of birth
# Keywords:  ['place of birth']
# P: place of birth, Q: Demond Wilson
# what
# Keyword:  cast member of Loners
# Keywords:  ['cast member of Loners']
# mask_p: Tell me the <> of Loners.
# ---Try model 3---
# Tell me the <> of Loners.
# No name entity was found.
# Q, mask_q: Loners Tell me the cast member of <>.
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Loners
# what
# Keyword:  country of citizenship of Brad Gilbert
# Keywords:  ['country of citizenship of Brad Gilbert']
# mask_p: Tell me the <> of Brad Gilbert.
# Q, mask_q: Brad Gilbert Tell me the country of citizenship of <>.
# Keyword:  country of citizenship
# Keywords:  ['country of citizenship']
# P: country of citizenship, Q: Brad Gilbert
# what
# Keyword:  IMDb ID of Secret Superstar
# Keywords:  ['IMDb ID of Secret Superstar']
# mask_p: Can you tell me the <> of Secret Superstar?
# Q, mask_q: Secret Superstar Can you tell me the IMDb ID of <>?
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: Secret Superstar
# what
# Answer factual questions failed.
# Keyword:  node description of Bartosz Bielenia
# Keywords:  ['node description of Bartosz Bielenia']
# mask_p: Can you tell me the node description of Bartosz Bielenia?
# Q, mask_q: Bartosz Bielenia Can you tell me the node description of <>?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Bartosz Bielenia
# Keyword:  cast member of Kaalapani
# Keywords:  ['cast member of Kaalapani']
# mask_p: Tell me the <> of Kaalapani.
# Q, mask_q: Kaalapani Tell me the cast member of <>.
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Kaalapani
# what
# Keyword:  node label of Josefina Vilsmaier
# Keywords:  ['node label of Josefina Vilsmaier']
# mask_p: Do you know the node <> of Josefina Vilsmaier?
# Q, mask_q: Josefina Vilsmaier Do you know the node label of <>?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Josefina Vilsmaier
# Keyword:  Ruth Becquart
# Keywords:  ['Ruth Becquart']
# mask_p: Can you tell me the instance of of Ruth Becquart?
# Q, mask_q: Ruth Becquart Can you tell me the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Ruth Becquart
# what
# Keyword:  genre of Beats
# Keywords:  ['genre of Beats']
# mask_p: Do you know the <> of Beats?
# Q, mask_q: Beats Do you know the genre of <>?
# Keyword:  genre
# Keywords:  ['genre']
# P: genre, Q: Beats
# what
# Keyword:  occupation of Tommy Kenter
# Keywords:  ['occupation of Tommy Kenter']
# mask_p: Do you know the <> of Tommy Kenter?
# Q, mask_q: Tommy Kenter Do you know the occupation of <>?
# Keyword:  occupation
# Keywords:  ['occupation']
# P: occupation, Q: Tommy Kenter
# what
# Keyword:  main subject of Dogville
# Keywords:  ['main subject of Dogville']
# mask_p: Can you tell me the <> of Dogville?
# Q, mask_q: Dogville Can you tell me the main subject of <>?
# Keyword:  main subject
# Keywords:  ['main subject']
# P: main subject, Q: Dogville
# what
# Keyword:  cast member of Belphegor
# Keywords:  ['cast member of Belphegor']
# mask_p: What is the <> of Belphegor, Phantom of the Louvre?
# Q, mask_q: Belphegor, Phantom of the Louvre What is the cast member of <>?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Belphegor, Phantom of the Louvre
# what
# Keyword:  filming location of Miracle at St. Anna
# Keywords:  ['filming location of Miracle at St. Anna']
# mask_p: Do you know the <> of Miracle at St. Anna?
# Q, mask_q: Miracle at St. Anna Do you know the filming location of <>?
# Keyword:  filming location
# Keywords:  ['filming location']
# P: filming location, Q: Miracle at St. Anna
# what
# Keyword:  fabrication method of Pom Poko
# Keywords:  ['fabrication method of Pom Poko']
# mask_p: What is the <> of Pom Poko?
# Q, mask_q: Pom Poko What is the fabrication method of <>?
# Keyword:  fabrication method
# Keywords:  ['fabrication method']
# P: fabrication method, Q: Pom Poko
# what
# Keyword:  Jane Doe
# Keywords:  ['Jane Doe']
# mask_p: Do you know the instance of of Jane Doe: Now You See It, Now You Don't?
# Q, mask_q: Jane Doe Do you know the instance of of <>: Now You See It, Now You Don't?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Jane Doe
# what
# Keyword:  Meredith Vieira
# Keywords:  ['Meredith Vieira']
# mask_p: Can you tell me the instance of of Meredith Vieira?
# Q, mask_q: Meredith Vieira Can you tell me the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Meredith Vieira
# what
# Keyword:  Young Karl Marx distributed
# Keywords:  ['Young Karl Marx distributed']
# mask_p: What is The Young Karl Marx distributed by?
# Q, mask_q: The Young Karl Marx What is <> distributed by?
# Keyword:  distributed
# Keywords:  ['distributed']
# P: distributed by, Q: The Young Karl Marx
# what
# Keyword:  Carrie
# Keywords:  ['Carrie']
# mask_p: What is the instance of of Carrie?
# Q, mask_q: Carrie What is the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Carrie
# what
# Keyword:  Spun distribution format
# Keywords:  ['Spun distribution format']
# mask_p: What is Spun's <>?
# Q, mask_q: Spun What is <>'s distribution format?
# Keyword:  distribution format
# Keywords:  ['distribution format']
# P: distribution format, Q: Spun
# what
# Keyword:  IMDb ID of Syrup
# Keywords:  ['IMDb ID of Syrup']
# mask_p: What is the <> of Syrup?
# Q, mask_q: S What is the IMDb ID of <>yrup?
# Keyword:  yrup
# Keywords:  ['yrup']
# P: sidekick of, Q: S
# what
# Answer factual questions failed.
# Keyword:  Shepherds and Butchers cast member
# Keywords:  ['Shepherds and Butchers cast member']
# mask_p: What is Shepherds and Butchers's <>?
# Q, mask_q: Shepherds and Butchers What is <>'s cast member?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Shepherds and Butchers
# what
# Keyword:  occupation of Gage Graham-Arbuthnot
# Keywords:  ['occupation of Gage Graham-Arbuthnot']
# mask_p: What is the <> of Gage Graham-Arbuthnot?
# Q, mask_q: Gage Graham-Arbuthnot What is the occupation of <>?
# Keyword:  occupation
# Keywords:  ['occupation']
# P: occupation, Q: Gage Graham-Arbuthnot
# what
# Keyword:  Marzena Bergmann
# Keywords:  ['Marzena Bergmann']
# mask_p: Can you tell me the instance of of Marzena Bergmann?
# Q, mask_q: Marzena Bergmann Can you tell me the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Marzena Bergmann
# what
# Keyword:  narrative location of Sin Nombre
# Keywords:  ['narrative location of Sin Nombre']
# mask_p: Can you tell me the <> of Sin Nombre?
# Q, mask_q: Sin Nombre Can you tell me the narrative location of <>?
# Keyword:  narrative location
# Keywords:  ['narrative location']
# P: narrative location, Q: Sin Nombre
# what
# Keyword:  spouse of Fritz Kortner
# Keywords:  ['spouse of Fritz Kortner']
# mask_p: Can you tell me the <> of Fritz Kortner?
# Q, mask_q: Fritz Kortner Can you tell me the spouse of <>?
# Keyword:  spouse
# Keywords:  ['spouse']
# P: spouse, Q: Fritz Kortner
# what
# Keyword:  narrative location of Sudden Impact
# Keywords:  ['narrative location of Sudden Impact']
# mask_p: Tell me the <> of Sudden Impact.
# Q, mask_q: Sudden Impact Tell me the narrative location of <>.
# Keyword:  narrative location
# Keywords:  ['narrative location']
# P: narrative location, Q: Sudden Impact
# what
# Keyword:  language of film or TV show of Porky
# Keywords:  ['language of film or TV show of Porky']
# mask_p: Do you know the <> of Porky's II: The Next Day?
# Q, mask_q: Porky's II: The Next Day Do you know the original language of film or TV show of <>?
# Keyword:  original language of film or TV show
# Keywords:  ['original language of film or TV show']
# P: original language of film or TV show, Q: Porky's II: The Next Day
# what
# Keyword:  Tomorrowland node description
# Keywords:  ['Tomorrowland node description']
# mask_p: What is Tomorrowland's node <>?
# Q, mask_q: Tomorrowland What is <>'s node description?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Tomorrowland
# Keyword:  Operation Condor distributed
# Keywords:  ['Operation Condor distributed']
# mask_p: Can you tell me what is Armour of God II: Operation Condor <>?
# Q, mask_q: Armour of God II: Operation Condor Can you tell me what is <> distributed by?
# Keyword:  distributed
# Keywords:  ['distributed']
# P: distributed by, Q: Armour of God II: Operation Condor
# what
# Keyword:  Kathryn Bigelow
# Keywords:  ['Kathryn Bigelow']
# mask_p: Do you know the instance of of Kathryn Bigelow?
# Q, mask_q: Kathryn Bigelow Do you know the instance of of <>?
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Kathryn Bigelow
# what
# Keyword:  node label of Irving Brecher
# Keywords:  ['node label of Irving Brecher']
# mask_p: Do you know the node <> of Irving Brecher?
# Q, mask_q: Irving Brecher Do you know the node label of <>?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Irving Brecher
# Keyword:  Heaven
# Keywords:  ['Heaven']
# mask_p: Tell me what is Heaven Sent different from.
# ---Try model 3---
# Q, mask_q: Heaven Tell me what is <> Sent different from.
# Use whole question
# Keywords:  ['Tell me what is <> Sent different from.']
# P: different from, Q: Heaven
# what
# Answer factual questions failed.
# Keyword:  IMDb ID of The Twins Effect
# Keywords:  ['IMDb ID of The Twins Effect']
# mask_p: What is the <> of The Twins Effect II?
# Q, mask_q: The Twins Effect II What is the IMDb ID of <>?
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: The Twins Effect II
# what
# Answer factual questions failed.
# Keyword:  node label of Geoffrey Horne
# Keywords:  ['node label of Geoffrey Horne']
# mask_p: Tell me the node <> of Geoffrey Horne.
# Q, mask_q: Geoffrey Horne Tell me the node label of <>.
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Geoffrey Horne
# Keyword:  IMDb ID of Toma Jovanović
# Keywords:  ['IMDb ID of Toma Jovanović']
# mask_p: Can you tell me the <> of Toma Jovanović?
# Q, mask_q: Toma Jovanović Can you tell me the IMDb ID of <>?
# Keyword:  IMDb
# Keywords:  ['IMDb']
# P: IMDb ID, Q: Toma Jovanović
# what
# Answer factual questions failed.
# Keyword:  Black Panther contributor to the creative work
# Keywords:  ['Black Panther contributor to the creative work']
# mask_p: What is Black Panther's <>?
# Q, mask_q: Black Panther What is <>'s contributor to the creative work or subject?
# Keyword:  contributor to the creative work or subject
# Keywords:  ['contributor to the creative work or subject']
# P: contributor to the creative work or subject, Q: Black Panther
# what
# Keyword:  Lena Nyman place of death
# Keywords:  ['Lena Nyman place of death']
# mask_p: What is Lena Nyman's <>?
# Q, mask_q: Lena Nyman What is <>'s place of death?
# Keyword:  place of death
# Keywords:  ['place of death']
# P: place of death, Q: Lena Nyman
# what
# Keyword:  node label of Ghost Town
# Keywords:  ['node label of Ghost Town']
# mask_p: Can you tell me the node <> of Ghost Town?
# Q, mask_q: Ghost Town Can you tell me the node label of <>?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Ghost Town
# Keyword:  node label of Toan
# Keywords:  ['node label of Toan']
# mask_p: What is the node <> of Toan Le?
# Q, mask_q: Toan Le What is the node label of <>?
# Keyword:  node label
# Keywords:  ['node label']
# P: label, Q: Toan Le
# Keyword:  Xavier Saint-Macary
# Keywords:  ['Xavier Saint-Macary']
# mask_p: Tell me the instance of of Xavier Saint-Macary.
# Q, mask_q: Xavier Saint-Macary Tell me the instance of of <>.
# Keyword:  instance
# Keywords:  ['instance']
# P: instance of, Q: Xavier Saint-Macary
# what
# Keyword:  Michael Kroecher languages spoken
# Keywords:  ['Michael Kroecher languages spoken']
# mask_p: What is Michael Kroecher's languages spoken, written or signed?
# Q, mask_q: Michael Kroecher What is <>'s languages spoken, written or signed?
# Keyword:  written or signed
# Keywords:  ['written or signed']
# P: languages spoken, written or signed, Q: Michael Kroecher
# what
# Keyword:  cast member of Rock Slyde
# Keywords:  ['cast member of Rock Slyde']
# mask_p: Tell me the <> of Rock Slyde.
# Q, mask_q: Rock Slyde Tell me the cast member of <>.
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: Rock Slyde
# what
# Keyword:  node description of Angels
# Keywords:  ['node description of Angels']
# mask_p: What is the node <> of Angels & Demons?
# Q, mask_q: Angels & Demons What is the node description of <>?
# Keyword:  node description
# Keywords:  ['node description']
# P: description, Q: Angels & Demons
# Keyword:  occupation of Stephen E. Miller
# Keywords:  ['occupation of Stephen E. Miller']
# mask_p: Tell me the occupation of Stephen E. Miller.
# Q, mask_q: Stephen E. Miller Tell me the occupation of <>.
# Keyword:  occupation
# Keywords:  ['occupation']
# P: occupation, Q: Stephen E. Miller
# what
# Keyword:  cast member of San Andreas
# Keywords:  ['cast member of San Andreas']
# mask_p: Do you know the <> of San Andreas?
# Q, mask_q: San Andreas Do you know the cast member of <>?
# Keyword:  cast member
# Keywords:  ['cast member']
# P: cast member, Q: San Andreas
# what
# Keyword:  Secret Superstar
# Keywords:  ['Secret Superstar']
# mask_p: Let me know what Secret Superstar looks like.
# Q, mask_q: Secret Superstar Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Secret Superstar
# Q28127548
# tt6108090
# Keyword:  Syrup
# Keywords:  ['Syrup']
# mask_p: What does Syrup look like?
# Q, mask_q: S What does <>yrup look like?
# Keyword:  yrup
# Keywords:  ['yrup']
# P: sidekick of, Q: S
# what
# Answer factual questions failed.
# Keyword:  Show me a picture of Totò
# Keywords:  ['Show me a picture of Totò']
# mask_p: Show me a picture of Totò?
# Q, mask_q: Totò Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Totò
# Q2291
# nm0869451
# Keyword:  Eddie Marr
# Keywords:  ['Eddie Marr']
# mask_p: Let me know what Eddie Marr looks like.
# Q, mask_q: Eddie Marr Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Eddie Marr
# Q3047288
# nm0549979
# Keyword:  Russell Johnson
# Keywords:  ['Russell Johnson']
# mask_p: Let me know what Russell Johnson looks like.
# Q, mask_q: Russell Johnson Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Russell Johnson
# Q1387828
# nm0426157
# Keyword:  Ren Ōsugi
# Keywords:  ['Ren Ōsugi']
# mask_p: Let me know what Ren Ōsugi looks like.
# Q, mask_q: Ren Ōsugi Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Ren Ōsugi
# Q1138332
# nm0652592
# Keyword:  Show me a picture of Kiki Delivery Service
# Keywords:  ['Show me a picture of Kiki Delivery Service']
# mask_p: Show me a picture of Kiki's Delivery Service?
# Q, mask_q: Kiki's Delivery Service Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Kiki's Delivery Service
# Q196602
# tt0097814
# Keyword:  Song Kang-ho
# Keywords:  ['Song Kang-ho']
# mask_p: What does Song Kang-ho look like?
# Q, mask_q: Song Kang-ho What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Song Kang-ho
# Q484400
# nm0814280
# Keyword:  Show me a picture of Tom Felton
# Keywords:  ['Show me a picture of Tom Felton']
# mask_p: Show me a picture of Tom Felton?
# Q, mask_q: Tom Felton Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Tom Felton
# Q105682
# nm0271657
# Keyword:  Show me a picture of Franco Nero
# Keywords:  ['Show me a picture of Franco Nero']
# mask_p: Show me a picture of Franco Nero?
# Q, mask_q: Franco Nero Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Franco Nero
# Q311716
# nm0626259
# Keyword:  Bent Fabric
# Keywords:  ['Bent Fabric']
# mask_p: Let me know what Bent Fabric looks like.
# Q, mask_q: Bent Fabric Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Bent Fabric
# Q712364
# nm0006065
# Keyword:  Whisper
# Keywords:  ['Whisper']
# mask_p: What does Whisper 2 look like?
# Q, mask_q: Whisper 2 What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Whisper 2
# Q19932817
# tt3849938
# Keyword:  picture of The Outlaw Josey Wales
# Keywords:  ['picture of The Outlaw Josey Wales']
# mask_p: Show me a picture of The Outlaw Josey Wales?
# Q, mask_q: The Outlaw Josey Wales Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: The Outlaw Josey Wales
# Q477630
# tt0075029
# Keyword:  Jon Øigarden
# Keywords:  ['Jon Øigarden']
# mask_p: What does Jon Øigarden look like?
# Q, mask_q: Jon Øigarden What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Jon Øigarden
# Q6271813
# nm0960276
# Keyword:  Show me a picture of Wrath
# Keywords:  ['Show me a picture of Wrath']
# mask_p: Show me a picture of Wrath of the Titans?
# Q, mask_q: Wrath of the Titans Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Wrath of the Titans
# Q226773
# tt1646987
# Keyword:  picture of Once Upon a Time in Mumbaai
# Keywords:  ['picture of Once Upon a Time in Mumbaai']
# mask_p: Show me a picture of Once Upon a Time in Mumbaai?
# Q, mask_q: Once Upon a Time in Mumbaai Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Once Upon a Time in Mumbaai
# Q7091871
# tt1395054
# Keyword:  Daytrippers
# Keywords:  ['Daytrippers']
# mask_p: Let me know what The Daytrippers looks like.
# Q, mask_q: The Daytrippers Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: The Daytrippers
# Q1778532
# tt0116041
# Keyword:  Dead Ringers
# Keywords:  ['Dead Ringers']
# mask_p: Let me know what Dead Ringers looks like.
# Q, mask_q: Dead Ringers Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Dead Ringers
# Q635569
# tt0094964
# Keyword:  Dragonfly
# Keywords:  ['Dragonfly']
# mask_p: Let me know what Dragonfly looks like.
# Q, mask_q: Dragonfly Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Dragonfly
# Q119341
# tt0259288
# Keyword:  Allen Williams
# Keywords:  ['Allen Williams']
# mask_p: Let me know what Allen Williams looks like.
# Q, mask_q: Allen Williams Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Allen Williams
# Q2648391
# nm0930006
# Keyword:  Show me a picture of Stephen Cone
# Keywords:  ['Show me a picture of Stephen Cone']
# mask_p: Show me a picture of Stephen Cone?
# Q, mask_q: Stephen Cone Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Stephen Cone
# Q17721805
# nm3265508
# Keyword:  Show me a picture of Christmas in Connecticut
# Keywords:  ['Show me a picture of Christmas in Connecticut']
# mask_p: Show me a picture of Christmas in Connecticut?
# Q, mask_q: Connecticut Show me a picture of Christmas in <>?
# Keyword:  Show me a picture of Christmas
# Keywords:  ['Show me a picture of Christmas']
# P: depicts, Q: Connecticut
# what
# Answer factual questions failed.
# Keyword:  Gold
# Keywords:  ['Gold']
# mask_p: What does Gold look like?
# Q, mask_q: Gold What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Gold
# Q966003
# tt0071566
# Keyword:  Show me a picture of Roger Allers
# Keywords:  ['Show me a picture of Roger Allers']
# mask_p: Show me a picture of Roger Allers?
# Q, mask_q: Roger Allers Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Roger Allers
# Q847468
# nm0021249
# Keyword:  Show me a picture of Arón Piper
# Keywords:  ['Show me a picture of Arón Piper']
# mask_p: Show me a picture of Arón Piper?
# Q, mask_q: Arón Piper Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Arón Piper
# Q56887586
# nm1422693
# Keyword:  Rudolf Hrušínský
# Keywords:  ['Rudolf Hrušínský']
# mask_p: Let me know what Rudolf Hrušínský looks like.
# Q, mask_q: Rudolf Hrušínský Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Rudolf Hrušínský
# Q444097
# nm0398703
# Keyword:  Ralf
# Keywords:  ['Ralf']
# mask_p: Let me know what Ralf Little looks like.
# Q, mask_q: Ralf Little Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Ralf Little
# Q2484359
# nm0514644
# Keyword:  Thom Green
# Keywords:  ['Thom Green']
# mask_p: What does Thom Green look like?
# Q, mask_q: Thom Green What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Thom Green
# Q998064
# nm2964015
# Keyword:  Show me a picture of Miroslav Šimůnek
# Keywords:  ['Show me a picture of Miroslav Šimůnek']
# mask_p: Show me a picture of Miroslav Šimůnek?
# Q, mask_q: Miroslav Šimůnek Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Miroslav Šimůnek
# Q12038047
# nm0801420
# Keyword:  Michael McManus
# Keywords:  ['Michael McManus']
# mask_p: What does Michael McManus look like?
# Q, mask_q: Michael McManus What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Michael McManus
# Q357686
# nm0573158
# Keyword:  Hunt for the Blood Orchid
# Keywords:  ['Hunt for the Blood Orchid']
# mask_p: Let me know what Anacondas: The Hunt for the Blood Orchid looks like.
# Q, mask_q: Anacondas: The Hunt for the Blood Orchid Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Anacondas: The Hunt for the Blood Orchid
# Q483591
# tt0366174
# Keyword:  Show me a picture of Annie Girardot
# Keywords:  ['Show me a picture of Annie Girardot']
# mask_p: Show me a picture of Annie Girardot?
# Q, mask_q: Annie Girardot Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Annie Girardot
# Q106443
# nm0320760
# Keyword:  Show me a picture of Natasha Gregson Wagner
# Keywords:  ['Show me a picture of Natasha Gregson Wagner']
# mask_p: Show me a picture of Natasha Gregson Wagner?
# Q, mask_q: Natasha Gregson Wagner Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Natasha Gregson Wagner
# Q240467
# nm0906031
# Keyword:  Show me a picture of Cindy Robinson
# Keywords:  ['Show me a picture of Cindy Robinson']
# mask_p: Show me a picture of Cindy Robinson?
# Q, mask_q: Cindy Robinson Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Cindy Robinson
# Q5120590
# nm0732480
# Keyword:  Carly Steel
# Keywords:  ['Carly Steel']
# mask_p: Let me know what Carly Steel looks like.
# Q, mask_q: Carly Steel Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Carly Steel
# Q15702396
# nm2945096
# Keyword:  Nakamura Baijaku
# Keywords:  ['Nakamura Baijaku']
# mask_p: Let me know what Nakamura Baijaku II looks like.
# Q, mask_q: Nakamura Baijaku II Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Nakamura Baijaku II
# Q3547153
# nm0620120
# Keyword:  Shannon Kook
# Keywords:  ['Shannon Kook']
# mask_p: What does Shannon Kook look like?
# Q, mask_q: Shannon Kook What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Shannon Kook
# Q13527911
# nm3651929
# Keyword:  Sam Gold
# Keywords:  ['Sam Gold']
# mask_p: What does Sam Gold look like?
# Q, mask_q: Sam Gold What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Sam Gold
# Q7407527
# nm3190307
# Keyword:  Show me a picture of Gerd Nefzer
# Keywords:  ['Show me a picture of Gerd Nefzer']
# mask_p: Show me a picture of Gerd Nefzer?
# Q, mask_q: Gerd Nefzer Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Gerd Nefzer
# Q47503052
# nm0275382
# Keyword:  Riccardo Zinna
# Keywords:  ['Riccardo Zinna']
# mask_p: What does Riccardo Zinna look like?
# Q, mask_q: Riccardo Zinna What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Riccardo Zinna
# Q3934653
# nm0957024
# Keyword:  Show me a picture of John Cale
# Keywords:  ['Show me a picture of John Cale']
# mask_p: Show me a picture of John Cale?
# Q, mask_q: John Cale Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: John Cale
# Q45909
# nm0129816
# Keyword:  Rhonda Stubbins White
# Keywords:  ['Rhonda Stubbins White']
# mask_p: What does Rhonda Stubbins White look like?
# Q, mask_q: Rhonda Stubbins White What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Rhonda Stubbins White
# Q23012364
# nm0925367
# Keyword:  Truth or Dare
# Keywords:  ['Truth or Dare']
# mask_p: What does Madonna: Truth or Dare look like?
# Q, mask_q: Madonna: Truth or Dare What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Madonna: Truth or Dare
# Q187561
# tt0102370
# Keyword:  Michel Serrault
# Keywords:  ['Michel Serrault']
# mask_p: What does Michel Serrault look like?
# Q, mask_q: Michel Serrault What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Michel Serrault
# Q318088
# nm0785664
# Keyword:  Jesse Welles
# Keywords:  ['Jesse Welles']
# mask_p: What does Jesse Welles look like?
# Q, mask_q: Jesse Welles What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Jesse Welles
# Q6186957
# nm0919934
# Keyword:  Show me a picture of Jobyna Ralston
# Keywords:  ['Show me a picture of Jobyna Ralston']
# mask_p: Show me a picture of Jobyna Ralston?
# Q, mask_q: Jobyna Ralston Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Jobyna Ralston
# Q1929752
# nm0707814
# Keyword:  Aldo Tonti
# Keywords:  ['Aldo Tonti']
# mask_p: Let me know what Aldo Tonti looks like.
# Q, mask_q: Aldo Tonti Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Aldo Tonti
# Q957569
# nm0005905
# Keyword:  Ward Bond
# Keywords:  ['Ward Bond']
# mask_p: What does Ward Bond look like?
# Q, mask_q: Ward Bond What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Ward Bond
# Q1280760
# nm0000955
# Keyword:  Angelica Lee
# Keywords:  ['Angelica Lee']
# mask_p: Let me know what Angelica Lee looks like.
# Q, mask_q: Angelica Lee Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Angelica Lee
# Q706623
# nm0496806
# Keyword:  Joy Lauren
# Keywords:  ['Joy Lauren']
# mask_p: What does Joy Lauren look like?
# Q, mask_q: Joy Lauren What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Joy Lauren
# Q242653
# nm1280053
# Keyword:  Shu Lan Tuan
# Keywords:  ['Shu Lan Tuan']
# mask_p: What does Shu Lan Tuan look like?
# Q, mask_q: Shu Lan Tuan What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Shu Lan Tuan
# Q24681807
# nm1234674
# Keyword:  Rob Liefeld
# Keywords:  ['Rob Liefeld']
# mask_p: What does Rob Liefeld look like?
# Q, mask_q: Rob Liefeld What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Rob Liefeld
# Q2061990
# nm0509580
# Keyword:  Show me a picture of Isabel Sanford
# Keywords:  ['Show me a picture of Isabel Sanford']
# mask_p: Show me a picture of Isabel Sanford?
# Q, mask_q: Isabel Sanford Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Isabel Sanford
# Q271863
# nm0762567
# Keyword:  Pradeep Kumar
# Keywords:  ['Pradeep Kumar']
# mask_p: What does Pradeep Kumar look like?
# Q, mask_q: Pradeep Kumar What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Pradeep Kumar
# Q7237409
# nm0474850
# Keyword:  Diamond White
# Keywords:  ['Diamond White']
# mask_p: Let me know what Diamond White looks like.
# Q, mask_q: Diamond White Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Diamond White
# Q16240338
# nm4024158
# Keyword:  Show me a picture of Glória Menezes
# Keywords:  ['Show me a picture of Glória Menezes']
# mask_p: Show me a picture of Glória Menezes?
# Q, mask_q: Glória Menezes Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Glória Menezes
# Q1754317
# nm0579510
# Keyword:  Rakhi Sawant
# Keywords:  ['Rakhi Sawant']
# mask_p: What does Rakhi Sawant look like?
# Q, mask_q: Rakhi Sawant What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Rakhi Sawant
# Q3543017
# nm1179156
# Use whole question
# Keywords:  ['Let me know what If Not Us, Who? looks like.']
# mask_p: Let me know what If Not Us, Who? looks like.
# Q, mask_q: Us Let me know what If Not <>, Who? looks like.
# Use whole question
# Keywords:  ['Let me know what If Not <>, Who? looks like.']
# P: look like, Q: Us
# Q56000996
# tt6857112
# Keyword:  Nicole Maines
# Keywords:  ['Nicole Maines']
# mask_p: Let me know what Nicole Maines looks like.
# Q, mask_q: Nicole Maines Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Nicole Maines
# Q33124715
# nm7414233
# Keyword:  Show me a picture of Trevor Cooper
# Keywords:  ['Show me a picture of Trevor Cooper']
# mask_p: Show me a picture of Trevor Cooper?
# Q, mask_q: Trevor Cooper Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Trevor Cooper
# Q7839105
# nm0178430
# Keyword:  Javier Drolas
# Keywords:  ['Javier Drolas']
# mask_p: What does Javier Drolas look like?
# Q, mask_q: Javier Drolas What does <> look like?
# Use whole question
# Keywords:  ['What does <> look like?']
# P: look like, Q: Javier Drolas
# Q5927668
# nm1404059
# Keyword:  Return to Halloweentown
# Keywords:  ['Return to Halloweentown']
# mask_p: Let me know what Return to Halloweentown looks like.
# Q, mask_q: Return to Halloweentown Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Return to Halloweentown
# Q1571871
# tt0816520
# Keyword:  Show me a picture of Matthew Betz
# Keywords:  ['Show me a picture of Matthew Betz']
# mask_p: Show me a picture of Matthew Betz?
# Q, mask_q: Matthew Betz Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Matthew Betz
# Q2112157
# nm0079490
# Keyword:  Manu Rishi
# Keywords:  ['Manu Rishi']
# mask_p: Let me know what Manu Rishi looks like.
# Q, mask_q: Manu Rishi Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Manu Rishi
# Q6752284
# nm2286188
# Keyword:  extraño viaje
# Keywords:  ['extraño viaje']
# mask_p: Let me know what El extraño viaje looks like.
# Q, mask_q: El extraño viaje Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: El extraño viaje
# Q5352428
# tt0061633
# Keyword:  Show me a picture of Squadron
# Keywords:  ['Show me a picture of Squadron']
# mask_p: Show me a picture of Squadron 303?
# Q, mask_q: Squadron 303 Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Squadron 303
# Q60596199
# tt5475734
# Keyword:  Show me a picture of Kalinka
# Keywords:  ['Show me a picture of Kalinka']
# mask_p: Show me a picture of Kalinka?
# Q, mask_q: Kalinka Show me a picture of <>?
# Keyword:  Show me a picture
# Keywords:  ['Show me a picture']
# P: image, Q: Kalinka
# Q22247982
# tt4228810
# Keyword:  Daniel MacPherson
# Keywords:  ['Daniel MacPherson']
# mask_p: Let me know what Daniel MacPherson looks like.
# Q, mask_q: Daniel MacPherson Let me know what <> looks like.
# Use whole question
# Keywords:  ['Let me know what <> looks like.']
# P: look like, Q: Daniel MacPherson
# Q2374646
# nm0534205
# ...
# drama
# Qids: ['Q1520037', 'Q5293904', 'Q1159835']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1054574', 'publication_date': None}
# romance film
# Qids: ['Q16630157', 'Q338599', 'Q20888800']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q7113411', 'Q55482173']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q1215609']
# {'director': 'http://www.wikidata.org/entity/Q1583894', 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# Hansjörg Thurn
# drama
# Qids: ['Q8029077', 'Q639228', 'Q643811', 'Q4533293']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q1347393', 'Q310427', 'Q567072']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q3095159', 'Q505525', 'Q426517']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q3222841', 'Q58411554', 'Q18124780', 'Q5905840']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q2348998', 'Q652592', 'Q461540']
# {'director': None, 'set_in_period': 'http://www.wikidata.org/entity/Q5268', 'genre': 'http://www.wikidata.org/entity/Q52207399', 'publication_date': None}
# 1944
# film based on a novel
# Qids: ['Q310427', 'Q7741016']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q550571', 'Q221846', 'Q17371327']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q319221', 'publication_date': None}
# adventure film
# Qids: ['Q1347278', 'Q430278']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q679034', 'Q60429642', 'Q28869464', 'Q2598731', 'Q471992']
# {'director': None, 'set_in_period': 'http://www.wikidata.org/entity/Q5609', 'genre': 'http://www.wikidata.org/entity/Q860626', 'publication_date': None}
# 1300
# romantic comedy
# Qids: ['Q18124780']
# {'director': 'http://www.wikidata.org/entity/Q55431', 'set_in_period': None, 'genre': None, 'publication_date': None}
# Wong Kar-wai
# Qids: ['Q61273551', 'Q17113858']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q771457', 'Q1211909', 'Q168602', 'Q484442', 'Q17630593', 'Q23006268']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1535153', 'publication_date': None}
# superhero film
# Qids: ['Q287326', 'Q6735129', 'Q47146', 'Q7129195']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1341051', 'publication_date': None}
# post-apocalyptic film
# Qids: ['Q1254860', 'Q14511981', 'Q1520037']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q20747599', 'Q2421448']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q831717', 'Q1367668', 'Q3412379', 'Q17371327']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q7146001', 'Q1800357', 'Q1347393', 'Q932814']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q27536704', 'Q813461']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q188473', 'publication_date': None}
# action film
# Qids: ['Q2419344', 'Q310427', 'Q4885074']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1342372', 'publication_date': None}
# monster film
# Qids: ['Q221846', 'Q51740']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157394', 'publication_date': None}
# fantasy film
# Qids: ['Q922857', 'Q898675', 'Q3322730', 'Q806092']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q20442589', 'publication_date': None}
# LGBT-related film
# Qids: ['Q28735806', 'Q329145']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q21404571', 'Q2894345', 'Q4279468']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q46996368', 'Q2816310', 'Q845157']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q5222196', 'Q61642191', 'Q2870390', 'Q471992']
# {'director': None, 'set_in_period': 'http://www.wikidata.org/entity/Q5609', 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# 1300
# drama
# Qids: ['Q338599', 'Q20888800', 'Q1036386', 'Q1645003', 'Q17104642', 'Q17104642']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q15270639', 'Q28529502', 'Q2018550', 'Q33605', 'Q28980109']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q188473', 'publication_date': None}
# action film
# Qids: ['Q18155835', 'Q691555', 'Q20720837']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q1159835', 'Q20430699', 'Q98521442', 'Q287326', 'Q14650496']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q188473', 'publication_date': None}
# action film
# Qids: ['Q1754631', 'Q9379924', 'Q126800', 'Q505525']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q17104642', 'Q3095159', 'Q63883382', 'Q28840410']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q3079765', 'Q4499343', 'Q287708']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q1083331', 'Q54718', 'Q3547574']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q8261', 'publication_date': None}
# novel
# Qids: ['Q61273551', 'Q221846', 'Q691555', 'Q671131', 'Q752021']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q4662712', 'Q7316542']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1054574', 'publication_date': None}
# romance film
# Qids: ['Q27335731', 'Q28735806', 'Q23013699']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q275180', 'Q3519798']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1054574', 'publication_date': None}
# romance film
# Qids: ['Q782751', 'Q430278', 'Q20201985', 'Q771457', 'Q1211909']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q20201985', 'Q2413633', 'Q2348998', 'Q61273551']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q188473', 'publication_date': None}
# action film
# Qids: ['Q106808026', 'Q550571', 'Q3224612']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q319221', 'publication_date': None}
# adventure film
# Qids: ['Q63883382', 'Q21404571', 'Q7033842']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q47064265', 'Q1215609', 'Q20430699', 'Q98521442']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q470585', 'Q28796230', 'Q21404571', 'Q463768']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q5571070', 'Q5232811', 'Q193710', 'Q1159835', 'Q1361274', 'Q17986183', 'Q5003876', 'Q76']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q11401', 'publication_date': None}
# hip hop music
# Qids: ['Q4279468', 'Q64568948', 'Q4732569']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q2678111', 'publication_date': None}
# action comedy film
# Qids: ['Q22260096', 'Q1501773', 'Q19879', 'Q28980127', 'Q1501773', 'Q28980099', 'Q106858742']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q2649653', 'Q832514']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q200092', 'publication_date': None}
# horror film
# Qids: ['Q654154', 'Q898675', 'Q3322730', 'Q1405016']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q842256', 'publication_date': None}
# musical film
# Qids: ['Q17371327', 'Q27442520']
# {'director': None, 'set_in_period': None, 'genre': None, 'publication_date': None}
# Qids: ['Q2816310', 'Q1347393', 'Q128848', 'Q1305299']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q151730', 'Q44085', 'Q2280159']
# {'director': None, 'set_in_period': 'http://www.wikidata.org/entity/Q34644', 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# 1980s
# drama
# Qids: ['Q18155835', 'Q7185497']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q3412379', 'Q28039669']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q28039669', 'Q3536188', 'Q833530', 'Q18603039']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1054574', 'publication_date': None}
# romance film
# Qids: ['Q4499343', 'Q7741016']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1054574', 'publication_date': None}
# romance film
# Qids: ['Q5212461']
# {'director': None, 'set_in_period': None, 'genre': None, 'publication_date': None}
# Qids: ['Q3306390', 'Q21404571', 'Q1159835', 'Q1347959', 'Q2413429', 'Q752021']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q379055', 'Q56244126', 'Q1888524', 'Q21036756', 'Q3224612']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q15609981', 'Q654154', 'Q1520037']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q129657', 'Q1198900', 'Q18438904']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q471839', 'publication_date': None}
# science fiction film
# Qids: ['Q168602', 'Q20720837']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1033891', 'publication_date': None}
# martial arts film
# Qids: ['Q28473143', 'Q2511329', 'Q5293904', 'Q1634476']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q17019453', 'Q1072224', 'Q835245', 'Q1166120']
# {'director': None, 'set_in_period': 'http://www.wikidata.org/entity/Q35024', 'genre': 'http://www.wikidata.org/entity/Q2484376', 'publication_date': None}
# 2000s
# thriller film
# Qids: ['Q3061723', 'Q1549480', 'Q4662712', 'Q23999890']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q12031282', 'Q14650496', 'Q778331', 'Q28039669']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q150949', 'Q29588607']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q10588224', 'Q470585', 'Q3195644', 'Q3278522', 'Q7129195', 'Q17371327']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q2624855', 'Q484442', 'Q99601314', 'Q1603068', 'Q19895776']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157394', 'publication_date': None}
# fantasy film
# Qids: ['Q1536329', 'Q7113411', 'Q2694852']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q2933985', 'Q567072', 'Q15270639', 'Q58411554']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q23999890', 'Q4499343', 'Q7113411', 'Q55729634', 'Q486164']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q859369', 'publication_date': None}
# comedy-drama
# Qids: ['Q542048', 'Q1301154', 'Q550571', 'Q16923201']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q1092399', 'Q104836850', 'Q3035721', 'Q648034', 'Q7078868', 'Q7032696', 'Q21404571']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1339864', 'publication_date': None}
# sport film
# Qids: ['Q2649653', 'Q4732569', 'Q1800357']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q200092', 'publication_date': None}
# horror film
# Qids: ['Q18155520', 'Q7185497', 'Q1305299']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q93204', 'publication_date': None}
# documentary film
# Qids: ['Q2300638', 'Q2816310', 'Q2075172', 'Q29588607']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q20430699', 'Q747803', 'Q98521442', 'Q184768', 'Q17371327', 'Q1169493']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q471839', 'publication_date': None}
# science fiction film
# Qids: ['Q898675', 'Q3322730', 'Q1977021', 'Q16531880', 'Q505525']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q157443', 'publication_date': None}
# comedy film
# Qids: ['Q1036386', 'Q1645003', 'Q1166120', 'Q4499343']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q1054574', 'publication_date': None}
# romance film
# Qids: ['Q18428', 'Q1405016', 'Q47509008', 'Q53110']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q2816310', 'Q3079765', 'Q287708']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q28980099', 'Q5613510', 'Q440759', 'Q27851', 'Q7091943', 'Q3024093']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# drama
# Qids: ['Q567072', 'Q1072224']
# {'director': None, 'set_in_period': 'http://www.wikidata.org/entity/Q35024', 'genre': 'http://www.wikidata.org/entity/Q130232', 'publication_date': None}
# 2000s
# drama
# Qids: ['Q654154', 'Q282781', 'Q3204952']
# {'director': None, 'set_in_period': None, 'genre': 'http://www.wikidata.org/entity/Q842256', 'publication_date': None}
# musical film
